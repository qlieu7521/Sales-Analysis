# %%
#!pip install pymysql

# %%
import pandas as pd
import numpy as np
import pymysql as mysql
import mysql.connector 
from mysql.connector import errorcode

# %%
#Import the data and check for null value
df = pd.read_csv('train.csv')
df["Order Date"] = pd.to_datetime(df["Order Date"],format='%Y-%m-%d')
df["Ship Date"] = pd.to_datetime(df["Ship Date"],format='%Y-%m-%d')
df['Sales'] = df['Sales'].round(2)
df['Profit'] = df['Profit'].round(2)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %%
# Check the potential key for data model
key_check = ['Row ID', 'Order ID', 'Customer ID', 'Postal Code', 'Product ID']

for x in key_check:
    print(x + ': ' + str(len(df[x].unique())))
# Out:
# Row ID: 9994
# Order ID: 5009
# Customer ID: 793
# Postal Code: 631
# Product ID: 1862

# %%
# Extract the transaction table and add key product_id
transaction = df[['Row ID', 'Order ID','Product ID','Sales', 'Product Name','Quantity','Discount','Profit']].copy()
dict ={'Row ID': 'transaction_id',
      'Order ID': 'order_id',
      'Product ID': 'product_code',
      'Sales': 'sales',
      'Product Name': 'product_name',
      'Quantity': 'quantity',
      'Discount': 'discount',
      'Profit': 'profit'}
transaction.rename(columns=dict, inplace=True)
transaction['product_id'] = pd.factorize(transaction['product_code'] + '_' + transaction['product_name'])[0]
transaction = transaction.drop(columns=['product_code','product_name'])
transaction
# Out:
#       transaction_id        order_id   sales  quantity  discount  profit  \
# 0                  1  CA-2016-152156  261.96         2      0.00   41.91
# 1                  2  CA-2016-152156  731.94         3      0.00  219.58
# 2                  3  CA-2016-138688   14.62         2      0.00    6.87
# 3                  4  US-2015-108966  957.58         5      0.45 -383.03
# 4                  5  US-2015-108966   22.37         2      0.20    2.52
# ...              ...             ...     ...       ...       ...     ...
# 9989            9990  CA-2014-110422   25.25         3      0.20    4.10
# 9990            9991  CA-2017-121258   91.96         2      0.00   15.63
# 9991            9992  CA-2017-121258  258.58         2      0.20   19.39
# 9992            9993  CA-2017-121258   29.60         4      0.00   13.32
# 9993            9994  CA-2017-119914  243.16         2      0.00   72.95
#
#       product_id
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 9989        1182
# 9990        1793
# 9991         298
# 9992         964
# 9993         167
#
# [9994 rows x 7 columns]

# %%
# Extract the order table and add key address_id
order = df[['Order ID','Order Date','Ship Date','Ship Mode','Customer ID','Customer Name','Segment','Postal Code','Country','Region','City','State']].copy()
dict = {'Order ID':'order_id','Order Date':'order_date','Ship Date':'ship_date','Ship Mode':'ship_mode','Customer ID':'customer_id','Customer Name':'customer_name','Segment':'segment','Postal Code':'postal_code','Country':'country','City':'city','State':'state','Region':'region'}
order.rename(columns=dict, inplace = True)
order['address_id'] = pd.factorize(order['postal_code'].astype(str) + '_' + order['country'] + '_' + order['region'] + '_' + order['city'] + '_' + order['state'])[0]
order.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       9994 non-null   object
#  1   order_date     9994 non-null   datetime64[ns]
#  2   ship_date      9994 non-null   datetime64[ns]
#  3   ship_mode      9994 non-null   object
#  4   customer_id    9994 non-null   object
#  5   customer_name  9994 non-null   object
#  6   segment        9994 non-null   object
#  7   postal_code    9994 non-null   int64
#  8   country        9994 non-null   object
#  9   region         9994 non-null   object
#  10  city           9994 non-null   object
#  11  state          9994 non-null   object
#  12  address_id     9994 non-null   int64
# dtypes: datetime64[ns](2), int64(2), object(9)
# memory usage: 1015.1+ KB

# %%
# Extract the Order_detailed table and remove duplicates
order_detailed = order[['order_id','order_date','ship_date','ship_mode','customer_id','address_id']]
order_detailed = order_detailed.drop_duplicates(subset=['order_id','order_date','ship_date','ship_mode'])
order_detailed
# Out:
#             order_id order_date  ship_date       ship_mode customer_id  \
# 0     CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5     CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 12    CA-2017-114412 2017-04-15 2017-04-20  Standard Class    AA-10480
# ...              ...        ...        ...             ...         ...
# 9986  CA-2016-125794 2016-09-29 2016-10-03  Standard Class    ML-17410
# 9987  CA-2017-163629 2017-11-17 2017-11-21  Standard Class    RA-19885
# 9989  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
#       address_id
# 0              0
# 2              1
# 3              2
# 5              3
# 12             4
# ...          ...
# 9986         141
# 9987         506
# 9989         123
# 9990         146
# 9993         279
#
# [5009 rows x 6 columns]

# %%
# Extract the customer Information table and remove duplicates
cus_info = order[['customer_id','customer_name','segment']]
cus_info = cus_info.drop_duplicates(subset=['customer_id'])
cus_info
# Out:
#      customer_id      customer_name      segment
# 0       CG-12520        Claire Gute     Consumer
# 2       DV-13045    Darrin Van Huff    Corporate
# 3       SO-20335     Sean O'Donnell     Consumer
# 5       BH-11710    Brosina Hoffman     Consumer
# 12      AA-10480       Andrew Allen     Consumer
# ...          ...                ...          ...
# 8666    CJ-11875       Carl Jackson    Corporate
# 9209    RS-19870         Roy Skaria  Home Office
# 9399    SC-20845         Sung Chung     Consumer
# 9441    RE-19405    Ricardo Emerson     Consumer
# 9558    SM-20905  Susan MacKendrick     Consumer
#
# [793 rows x 3 columns]

# %%
# Extract the customer address table and remove duplicates
cus_ad= order[['address_id', 'postal_code','country','region','city','state']]
cus_ad = cus_ad.drop_duplicates(subset='address_id')
cus_ad['postal_code']=cus_ad['postal_code'].fillna(1)
cus_ad
# Out:
#       address_id  postal_code        country   region             city  \
# 0              0        42420  United States    South        Henderson
# 2              1        90036  United States     West      Los Angeles
# 3              2        33311  United States    South  Fort Lauderdale
# 5              3        90032  United States     West      Los Angeles
# 12             4        28027  United States    South          Concord
# ...          ...          ...            ...      ...              ...
# 9760         627        72762  United States    South       Springdale
# 9801         628        95240  United States     West             Lodi
# 9834         629        77571  United States  Central         La Porte
# 9868         630        45040  United States     East            Mason
# 9881         631        30188  United States    South        Woodstock
#
#                state
# 0           Kentucky
# 2         California
# 3            Florida
# 5         California
# 12    North Carolina
# ...              ...
# 9760        Arkansas
# 9801      California
# 9834           Texas
# 9868            Ohio
# 9881         Georgia
#
# [632 rows x 6 columns]

# %%
# Extract the sub categories table and remove duplicates
sub_cat = df[['Category','Sub-Category']].copy()
sub_cat=sub_cat.rename(columns={'Category':'categories','Sub-Category':'sub_categories'})
sub_cat=sub_cat.drop_duplicates(subset=['sub_categories'])
sub_cat
# Out:
#           categories sub_categories
# 0          Furniture      Bookcases
# 1          Furniture         Chairs
# 2    Office Supplies         Labels
# 3          Furniture         Tables
# 4    Office Supplies        Storage
# 5          Furniture    Furnishings
# 6    Office Supplies            Art
# 7         Technology         Phones
# 8    Office Supplies        Binders
# 9    Office Supplies     Appliances
# 12   Office Supplies          Paper
# 26        Technology    Accessories
# 30   Office Supplies      Envelopes
# 53   Office Supplies      Fasteners
# 138  Office Supplies       Supplies
# 165       Technology       Machines
# 335       Technology        Copiers

# %%
# Extract the product table, add key product_id and remove duplicates
product = df[['Product ID','Sub-Category','Product Name']].copy()
dict = {'Product ID':'product_code','Category':'category','Sub-Category':'sub_categories','Product Name':'product_name'}
product.rename(columns=dict, inplace = True)
product['product_id'] = pd.factorize(product['product_code'] + '_' + product['product_name'])[0]
product=product.drop_duplicates(subset=['product_id'])
product
# Out:
#          product_code sub_categories  \
# 0     FUR-BO-10001798      Bookcases
# 1     FUR-CH-10000454         Chairs
# 2     OFF-LA-10000240         Labels
# 3     FUR-TA-10000577         Tables
# 4     OFF-ST-10000760        Storage
# ...               ...            ...
# 9521  TEC-PH-10002817         Phones
# 9562  TEC-MA-10003589       Machines
# 9604  OFF-AP-10003099     Appliances
# 9673  TEC-PH-10002645         Phones
# 9935  OFF-ST-10001627        Storage
#
#                                            product_name  product_id
# 0                     Bush Somerset Collection Bookcase           0
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...           1
# 2     Self-Adhesive Address Labels for Typewriters b...           2
# 3         Bretford CR4500 Series Slim Rectangular Table           3
# 4                        Eldon Fold 'N Roll Cart System           4
# ...                                                 ...         ...
# 9521                    RCA ViSYS 25425RE1 Corded phone        1889
# 9562                       Cisco 8961 IP Phone Charcoal        1890
# 9604                        Eureka Hand Vacuum, Bagless        1891
# 9673                                              LG G2        1892
# 9935  Eldon Jumbo ProFile Portable File Boxes Graphi...        1893
#
# [1894 rows x 4 columns]

# %%
# Extract the customer table and remove duplicates
cus_iden = cus_info[['customer_id','customer_name','segment']].copy()
cus_iden = cus_iden.drop_duplicates(subset='customer_id')
cus_iden
# Out:
#      customer_id      customer_name      segment
# 0       CG-12520        Claire Gute     Consumer
# 2       DV-13045    Darrin Van Huff    Corporate
# 3       SO-20335     Sean O'Donnell     Consumer
# 5       BH-11710    Brosina Hoffman     Consumer
# 12      AA-10480       Andrew Allen     Consumer
# ...          ...                ...          ...
# 8666    CJ-11875       Carl Jackson    Corporate
# 9209    RS-19870         Roy Skaria  Home Office
# 9399    SC-20845         Sung Chung     Consumer
# 9441    RE-19405    Ricardo Emerson     Consumer
# 9558    SM-20905  Susan MacKendrick     Consumer
#
# [793 rows x 3 columns]

# %%
# Connecting to the local MySQL database
cnx = mysql.connector.connect(user='root', password='Mayvitinh1995$',
                              database='superstore')
cursor = cnx.cursor(buffered=True)

# %%
# Prepare the query scripts for create table in the database
TABLES = {}
TABLES['product'] = (
    "CREATE TABLE `product` ("
    "  `product_code` varchar(65) NOT NULL,"
    "  `sub_categories` varchar(45) NOT NULL,"
    "  `product_name` varchar(1000) NOT NULL,"
    "  `product_id` int NOT NULL,"
    "  PRIMARY KEY (`product_id`)"
    ") ENGINE=InnoDB")

TABLES['transaction'] = (
    "CREATE TABLE `transaction` ("
    "  `transaction_id` int NOT NULL,"
    "  `order_id` varchar(45) NOT NULL,"
    "  `product_id` int NOT NULL,"
    "  `sales` numeric(10,2) NOT NULL,"
    "  `quantity` int NOT NULL,"
    "  `discount` numeric(10,2) NOT NULL,"
    "  `profit` numeric(10,2) NOT NULL,"
    "  PRIMARY KEY (`transaction_id`)"
    ") ENGINE=InnoDB")

TABLES['order_detailed'] = (
    "CREATE TABLE `order_detailed` ("
    "  `order_id` varchar(65) NOT NULL,"
    "  `order_date` date NOT NULL,"
    "  `ship_date` date NOT NULL,"
    "  `ship_mode` varchar(45) NOT NULL,"
    "  `customer_id` varchar(45) NOT NULL,"
    "  `address_id` int NOT NULL,"
    "  PRIMARY KEY (`order_id`)"
    ") ENGINE=InnoDB")

TABLES['customer_address'] = (
    "CREATE TABLE `customer_address` ("
    "  `address_id` int NOT NULL,"
    "  `city` varchar(45) NOT NULL,"
    "  `state` varchar(45) NOT NULL,"
    "  `region` varchar(45) NOT NULL,"
    "  `postal_code` int NOT NULL,"
    "  `country` varchar(45) NOT NULL,"
    "  PRIMARY KEY (`address_id`)"
    ") ENGINE=InnoDB")

TABLES['customer_information'] = (
    "CREATE TABLE `customer_information` ("
    "  `customer_id` varchar(65) NOT NULL,"
    "  `customer_name` varchar(45) NOT NULL,"
    "  `segment` varchar(45) NOT NULL,"
    "  PRIMARY KEY (`customer_id`)"
    ") ENGINE=InnoDB")


TABLES['product_detailed'] = (
    "CREATE TABLE `product_detailed` ("
    "  `sub_categories` varchar(65) NOT NULL,"
    "  `categories` varchar(45) NOT NULL,"
    "  PRIMARY KEY (`sub_categories`)"
    ") ENGINE=InnoDB")

# %%
# Run the SQL scripts to drop all potential tables if exist
table_names = ['transaction', 'product', 'order_detailed', 'customer_address', 'customer_information', 'product_detailed']
for i in table_names:
    cursor.execute("DROP TABLE IF EXISTS " + i)

# %%
# Check the tables in database
cursor.execute("show tables")
for x in cursor:
  print(x)

# %%
#Cretae the tables in databse
for table_name in TABLES:
    table_description = TABLES[table_name]
    try:
        print("Creating table {}: ".format(table_name), end='')
        cursor.execute(table_description)
    except mysql.connector.Error as err:
        if err.errno == errorcode.ER_TABLE_EXISTS_ERROR:
            print("already exists.")
        else:
            print(err.msg)
    else:
        print("OK")
# Out:
# Creating table product: OK
# Creating table transaction: OK
# Creating table order_detailed: OK
# Creating table customer_address: OK
# Creating table customer_information: OK
# Creating table product_detailed: OK

# %%
# Load the data into tables in datbase
dfs = [transaction, product, order_detailed, cus_ad, cus_iden, sub_cat]

for df, table_name in zip(dfs, table_names):
    cols = ",".join([str(i) for i in df.columns.tolist()])
    for i, row in df.iterrows():
        sql = "INSERT INTO " + table_name + " (" + cols + ") VALUES (" + "%s," * (len(row) - 1) + "%s)"
        cursor.execute(sql, tuple(row))
        cnx.commit()

# %%
# Check if loading successfully
cursor.execute("SELECT * FROM walmart.transaction")
for x in cursor:
    print(x)
# Out:
# (1, 'CA-2016-152156', 0, Decimal('261.96'), 2, Decimal('0.00'), Decimal('41.91'))
# (2, 'CA-2016-152156', 1, Decimal('731.94'), 3, Decimal('0.00'), Decimal('219.58'))
# (3, 'CA-2016-138688', 2, Decimal('14.62'), 2, Decimal('0.00'), Decimal('6.87'))
# (4, 'US-2015-108966', 3, Decimal('957.58'), 5, Decimal('0.45'), Decimal('-383.03'))
# (5, 'US-2015-108966', 4, Decimal('22.37'), 2, Decimal('0.20'), Decimal('2.52'))
# (6, 'CA-2014-115812', 5, Decimal('48.86'), 7, Decimal('0.00'), Decimal('14.17'))
# (7, 'CA-2014-115812', 6, Decimal('7.28'), 4, Decimal('0.00'), Decimal('1.97'))
# (8, 'CA-2014-115812', 7, Decimal('907.15'), 6, Decimal('0.20'), Decimal('90.72'))
# (9, 'CA-2014-115812', 8, Decimal('18.50'), 3, Decimal('0.20'), Decimal('5.78'))
# (10, 'CA-2014-115812', 9, Decimal('114.90'), 5, Decimal('0.00'), Decimal('34.47'))
# (11, 'CA-2014-115812', 10, Decimal('1706.18'), 9, Decimal('0.20'), Decimal('85.31'))
# (12, 'CA-2014-115812', 11, Decimal('911.42'), 4, Decimal('0.20'), Decimal('68.36'))
# (13, 'CA-2017-114412', 12, Decimal('15.55'), 3, Decimal('0.20'), Decimal('5.44'))
# (14, 'CA-2016-161389', 13, Decimal('407.98'), 3, Decimal('0.20'), Decimal('132.59'))
# (15, 'US-2015-118983', 14, Decimal('68.81'), 5, Decimal('0.80'), Decimal('-123.86'))
# (16, 'US-2015-118983', 15, Decimal('2.54'), 3, Decimal('0.80'), Decimal('-3.82'))
# (17, 'CA-2014-105893', 16, Decimal('665.88'), 6, Decimal('0.00'), Decimal('13.32'))
# (18, 'CA-2014-167164', 17, Decimal('55.50'), 2, Decimal('0.00'), Decimal('9.99'))
# (19, 'CA-2014-143336', 18, Decimal('8.56'), 2, Decimal('0.00'), Decimal('2.48'))
# (20, 'CA-2014-143336', 19, Decimal('213.48'), 3, Decimal('0.20'), Decimal('16.01'))
# (21, 'CA-2014-143336', 20, Decimal('22.72'), 4, Decimal('0.20'), Decimal('7.38'))
# (22, 'CA-2016-137330', 21, Decimal('19.46'), 7, Decimal('0.00'), Decimal('5.06'))
# (23, 'CA-2016-137330', 22, Decimal('60.34'), 7, Decimal('0.00'), Decimal('15.69'))
# (24, 'US-2017-156909', 23, Decimal('71.37'), 2, Decimal('0.30'), Decimal('-1.02'))
# (25, 'CA-2015-106320', 3, Decimal('1044.63'), 3, Decimal('0.00'), Decimal('240.26'))
# (26, 'CA-2016-121755', 24, Decimal('11.65'), 2, Decimal('0.20'), Decimal('4.22'))
# (27, 'CA-2016-121755', 25, Decimal('90.57'), 3, Decimal('0.00'), Decimal('11.77'))
# (28, 'US-2015-150630', 26, Decimal('3083.43'), 7, Decimal('0.50'), Decimal('-1665.05'))
# (29, 'US-2015-150630', 27, Decimal('9.62'), 2, Decimal('0.70'), Decimal('-7.05'))
# (30, 'US-2015-150630', 28, Decimal('124.20'), 3, Decimal('0.20'), Decimal('15.52'))
# (31, 'US-2015-150630', 29, Decimal('3.26'), 2, Decimal('0.20'), Decimal('1.10'))
# (32, 'US-2015-150630', 30, Decimal('86.30'), 6, Decimal('0.20'), Decimal('9.71'))
# (33, 'US-2015-150630', 31, Decimal('6.86'), 6, Decimal('0.70'), Decimal('-5.72'))
# (34, 'US-2015-150630', 32, Decimal('15.76'), 2, Decimal('0.20'), Decimal('3.55'))
# (35, 'CA-2017-107727', 33, Decimal('29.47'), 3, Decimal('0.20'), Decimal('9.95'))
# (36, 'CA-2016-117590', 34, Decimal('1097.54'), 7, Decimal('0.20'), Decimal('123.47'))
# (37, 'CA-2016-117590', 35, Decimal('190.92'), 5, Decimal('0.60'), Decimal('-147.96'))
# (38, 'CA-2015-117415', 36, Decimal('113.33'), 9, Decimal('0.20'), Decimal('35.42'))
# (39, 'CA-2015-117415', 37, Decimal('532.40'), 3, Decimal('0.32'), Decimal('-46.98'))
# (40, 'CA-2015-117415', 38, Decimal('212.06'), 3, Decimal('0.30'), Decimal('-15.15'))
# (41, 'CA-2015-117415', 39, Decimal('371.17'), 4, Decimal('0.20'), Decimal('41.76'))
# (42, 'CA-2017-120999', 40, Decimal('147.17'), 4, Decimal('0.20'), Decimal('16.56'))
# (43, 'CA-2016-101343', 41, Decimal('77.88'), 2, Decimal('0.00'), Decimal('3.89'))
# (44, 'CA-2017-139619', 42, Decimal('95.62'), 2, Decimal('0.20'), Decimal('9.56'))
# (45, 'CA-2016-118255', 43, Decimal('45.98'), 2, Decimal('0.00'), Decimal('19.77'))
# (46, 'CA-2016-118255', 44, Decimal('17.46'), 2, Decimal('0.00'), Decimal('8.21'))
# (47, 'CA-2014-146703', 45, Decimal('211.96'), 4, Decimal('0.00'), Decimal('8.48'))
# (48, 'CA-2016-169194', 46, Decimal('45.00'), 3, Decimal('0.00'), Decimal('4.95'))
# (49, 'CA-2016-169194', 47, Decimal('21.80'), 2, Decimal('0.00'), Decimal('6.10'))
# (50, 'CA-2015-115742', 48, Decimal('38.22'), 6, Decimal('0.00'), Decimal('17.96'))
# (51, 'CA-2015-115742', 49, Decimal('75.18'), 6, Decimal('0.00'), Decimal('35.33'))
# (52, 'CA-2015-115742', 50, Decimal('6.16'), 2, Decimal('0.00'), Decimal('2.96'))
# (53, 'CA-2015-115742', 51, Decimal('89.99'), 1, Decimal('0.00'), Decimal('17.10'))
# (54, 'CA-2016-105816', 52, Decimal('15.26'), 7, Decimal('0.00'), Decimal('6.26'))
# (55, 'CA-2016-105816', 53, Decimal('1029.95'), 5, Decimal('0.00'), Decimal('298.69'))
# (56, 'CA-2016-111682', 54, Decimal('208.56'), 6, Decimal('0.00'), Decimal('52.14'))
# (57, 'CA-2016-111682', 55, Decimal('32.40'), 5, Decimal('0.00'), Decimal('15.55'))
# (58, 'CA-2016-111682', 56, Decimal('319.41'), 5, Decimal('0.10'), Decimal('7.10'))
# (59, 'CA-2016-111682', 57, Decimal('14.56'), 2, Decimal('0.00'), Decimal('6.99'))
# (60, 'CA-2016-111682', 46, Decimal('30.00'), 2, Decimal('0.00'), Decimal('3.30'))
# (61, 'CA-2016-111682', 58, Decimal('48.48'), 4, Decimal('0.20'), Decimal('16.36'))
# (62, 'CA-2016-111682', 59, Decimal('1.68'), 1, Decimal('0.00'), Decimal('0.84'))
# (63, 'CA-2015-135545', 60, Decimal('13.98'), 2, Decimal('0.00'), Decimal('6.15'))
# (64, 'CA-2015-135545', 61, Decimal('25.82'), 6, Decimal('0.20'), Decimal('9.36'))
# (65, 'CA-2015-135545', 62, Decimal('146.73'), 3, Decimal('0.00'), Decimal('68.96'))
# (66, 'CA-2015-135545', 63, Decimal('79.76'), 4, Decimal('0.00'), Decimal('22.33'))
# (67, 'US-2015-164175', 64, Decimal('213.12'), 5, Decimal('0.30'), Decimal('-15.22'))
# (68, 'CA-2014-106376', 65, Decimal('1113.02'), 8, Decimal('0.20'), Decimal('111.30'))
# (69, 'CA-2014-106376', 66, Decimal('167.97'), 4, Decimal('0.20'), Decimal('62.99'))
# (70, 'CA-2016-119823', 67, Decimal('75.88'), 2, Decimal('0.00'), Decimal('35.66'))
# (71, 'CA-2016-106075', 68, Decimal('4.62'), 1, Decimal('0.20'), Decimal('1.73'))
# (72, 'CA-2017-114440', 69, Decimal('19.05'), 3, Decimal('0.00'), Decimal('8.76'))
# (73, 'US-2015-134026', 70, Decimal('831.94'), 8, Decimal('0.20'), Decimal('-114.39'))
# (74, 'US-2015-134026', 71, Decimal('97.04'), 2, Decimal('0.20'), Decimal('1.21'))
# (75, 'US-2015-134026', 72, Decimal('72.78'), 1, Decimal('0.20'), Decimal('-18.20'))
# (76, 'US-2017-118038', 73, Decimal('1.25'), 3, Decimal('0.80'), Decimal('-1.93'))
# (77, 'US-2017-118038', 74, Decimal('9.71'), 3, Decimal('0.60'), Decimal('-5.82'))
# (78, 'US-2017-118038', 75, Decimal('27.24'), 3, Decimal('0.20'), Decimal('2.72'))
# (79, 'US-2014-147606', 76, Decimal('19.30'), 5, Decimal('0.60'), Decimal('-14.48'))
# (80, 'CA-2016-127208', 77, Decimal('208.16'), 1, Decimal('0.00'), Decimal('56.20'))
# (81, 'CA-2016-127208', 78, Decimal('16.74'), 3, Decimal('0.00'), Decimal('8.04'))
# (82, 'CA-2014-139451', 79, Decimal('14.90'), 5, Decimal('0.00'), Decimal('4.17'))
# (83, 'CA-2014-139451', 80, Decimal('21.39'), 1, Decimal('0.00'), Decimal('6.20'))
# (84, 'CA-2015-149734', 81, Decimal('200.98'), 7, Decimal('0.20'), Decimal('62.81'))
# (85, 'US-2017-119662', 82, Decimal('230.38'), 3, Decimal('0.20'), Decimal('-48.95'))
# (86, 'CA-2017-140088', 83, Decimal('301.96'), 2, Decimal('0.00'), Decimal('33.22'))
# (87, 'CA-2017-155558', 84, Decimal('19.99'), 1, Decimal('0.00'), Decimal('6.80'))
# (88, 'CA-2017-155558', 85, Decimal('6.16'), 2, Decimal('0.00'), Decimal('2.96'))
# (89, 'CA-2016-159695', 86, Decimal('158.37'), 7, Decimal('0.20'), Decimal('13.86'))
# (90, 'CA-2016-109806', 87, Decimal('20.10'), 3, Decimal('0.00'), Decimal('6.63'))
# (91, 'CA-2016-109806', 40, Decimal('73.58'), 2, Decimal('0.20'), Decimal('8.28'))
# (92, 'CA-2016-109806', 88, Decimal('6.48'), 1, Decimal('0.00'), Decimal('3.11'))
# (93, 'CA-2015-149587', 89, Decimal('12.96'), 2, Decimal('0.00'), Decimal('6.22'))
# (94, 'CA-2015-149587', 90, Decimal('53.34'), 3, Decimal('0.00'), Decimal('16.54'))
# (95, 'CA-2015-149587', 91, Decimal('32.96'), 2, Decimal('0.00'), Decimal('16.15'))
# (96, 'US-2017-109484', 92, Decimal('5.68'), 1, Decimal('0.70'), Decimal('-3.79'))
# (97, 'CA-2017-161018', 93, Decimal('96.53'), 7, Decimal('0.00'), Decimal('40.54'))
# (98, 'CA-2017-157833', 94, Decimal('51.31'), 3, Decimal('0.20'), Decimal('17.96'))
# (99, 'CA-2016-149223', 95, Decimal('77.88'), 6, Decimal('0.00'), Decimal('22.59'))
# (100, 'CA-2016-158568', 96, Decimal('64.62'), 7, Decimal('0.20'), Decimal('22.62'))
# (101, 'CA-2016-158568', 97, Decimal('95.98'), 3, Decimal('0.20'), Decimal('-10.80'))
# (102, 'CA-2016-158568', 98, Decimal('1.79'), 3, Decimal('0.80'), Decimal('-3.04'))
# (103, 'CA-2016-129903', 99, Decimal('23.92'), 4, Decimal('0.00'), Decimal('11.72'))
# (104, 'US-2015-156867', 100, Decimal('238.90'), 6, Decimal('0.20'), Decimal('-26.88'))
# (105, 'US-2015-156867', 101, Decimal('102.36'), 3, Decimal('0.20'), Decimal('-3.84'))
# (106, 'US-2015-156867', 102, Decimal('36.88'), 3, Decimal('0.70'), Decimal('-25.82'))
# (107, 'CA-2017-119004', 103, Decimal('74.11'), 8, Decimal('0.20'), Decimal('17.60'))
# (108, 'CA-2017-119004', 104, Decimal('27.99'), 1, Decimal('0.20'), Decimal('2.10'))
# (109, 'CA-2017-119004', 105, Decimal('3.30'), 1, Decimal('0.20'), Decimal('1.07'))
# (110, 'CA-2015-129476', 106, Decimal('339.96'), 5, Decimal('0.20'), Decimal('67.99'))
# (111, 'CA-2017-146780', 107, Decimal('41.96'), 2, Decimal('0.00'), Decimal('10.91'))
# (112, 'CA-2016-128867', 108, Decimal('75.96'), 2, Decimal('0.00'), Decimal('22.79'))
# (113, 'CA-2016-128867', 109, Decimal('27.24'), 6, Decimal('0.00'), Decimal('13.35'))
# (114, 'CA-2014-115259', 110, Decimal('40.10'), 14, Decimal('0.20'), Decimal('14.53'))
# (115, 'CA-2014-115259', 111, Decimal('4.72'), 2, Decimal('0.20'), Decimal('1.65'))
# (116, 'CA-2014-115259', 112, Decimal('23.98'), 3, Decimal('0.20'), Decimal('7.49'))
# (117, 'CA-2014-115259', 113, Decimal('130.46'), 6, Decimal('0.20'), Decimal('44.03'))
# (118, 'CA-2015-110457', 114, Decimal('787.53'), 3, Decimal('0.00'), Decimal('165.38'))
# (119, 'US-2015-136476', 115, Decimal('157.79'), 1, Decimal('0.70'), Decimal('-115.72'))
# (120, 'CA-2016-103730', 116, Decimal('47.04'), 3, Decimal('0.00'), Decimal('18.35'))
# (121, 'CA-2016-103730', 8, Decimal('30.84'), 4, Decimal('0.00'), Decimal('13.88'))
# (122, 'CA-2016-103730', 117, Decimal('226.56'), 6, Decimal('0.00'), Decimal('63.44'))
# (123, 'CA-2016-103730', 118, Decimal('115.02'), 9, Decimal('0.00'), Decimal('51.76'))
# (124, 'CA-2016-103730', 119, Decimal('68.04'), 7, Decimal('0.00'), Decimal('19.73'))
# (125, 'US-2014-152030', 120, Decimal('600.56'), 3, Decimal('0.30'), Decimal('-8.58'))
# (126, 'US-2014-134614', 121, Decimal('617.70'), 6, Decimal('0.50'), Decimal('-407.68'))
# (127, 'US-2017-107272', 122, Decimal('2.39'), 2, Decimal('0.70'), Decimal('-1.83'))
# (128, 'US-2017-107272', 123, Decimal('243.99'), 7, Decimal('0.20'), Decimal('30.50'))
# (129, 'US-2016-125969', 124, Decimal('81.42'), 2, Decimal('0.20'), Decimal('-9.16'))
# (130, 'US-2016-125969', 125, Decimal('238.56'), 3, Decimal('0.00'), Decimal('26.24'))
# (131, 'US-2017-164147', 126, Decimal('59.97'), 5, Decimal('0.40'), Decimal('-11.99'))
# (132, 'US-2017-164147', 127, Decimal('78.30'), 2, Decimal('0.20'), Decimal('29.36'))
# (133, 'US-2017-164147', 128, Decimal('21.46'), 9, Decimal('0.20'), Decimal('6.97'))
# (134, 'CA-2016-145583', 129, Decimal('20.04'), 3, Decimal('0.00'), Decimal('9.62'))
# (135, 'CA-2016-145583', 130, Decimal('35.44'), 1, Decimal('0.00'), Decimal('16.66'))
# (136, 'CA-2016-145583', 131, Decimal('11.52'), 4, Decimal('0.00'), Decimal('3.46'))
# (137, 'CA-2016-145583', 132, Decimal('4.02'), 2, Decimal('0.00'), Decimal('1.97'))
# (138, 'CA-2016-145583', 133, Decimal('76.18'), 3, Decimal('0.20'), Decimal('26.66'))
# (139, 'CA-2016-145583', 134, Decimal('65.88'), 6, Decimal('0.00'), Decimal('18.45'))
# (140, 'CA-2016-145583', 50, Decimal('43.12'), 14, Decimal('0.00'), Decimal('20.70'))
# (141, 'CA-2016-110366', 28, Decimal('82.80'), 2, Decimal('0.20'), Decimal('10.35'))
# (142, 'CA-2017-106180', 135, Decimal('8.82'), 3, Decimal('0.00'), Decimal('2.38'))
# (143, 'CA-2017-106180', 136, Decimal('10.86'), 3, Decimal('0.00'), Decimal('5.10'))
# (144, 'CA-2017-106180', 137, Decimal('143.70'), 3, Decimal('0.00'), Decimal('68.98'))
# (145, 'CA-2017-155376', 138, Decimal('839.43'), 3, Decimal('0.00'), Decimal('218.25'))
# (146, 'CA-2015-110744', 82, Decimal('671.93'), 7, Decimal('0.00'), Decimal('20.16'))
# (147, 'CA-2014-110072', 139, Decimal('93.89'), 4, Decimal('0.20'), Decimal('12.91'))
# (148, 'CA-2016-114489', 140, Decimal('384.45'), 11, Decimal('0.00'), Decimal('103.80'))
# (149, 'CA-2016-114489', 141, Decimal('149.97'), 3, Decimal('0.00'), Decimal('6.00'))
# (150, 'CA-2016-114489', 1, Decimal('1951.84'), 8, Decimal('0.00'), Decimal('585.55'))
# (151, 'CA-2016-114489', 142, Decimal('171.55'), 5, Decimal('0.00'), Decimal('80.63'))
# (152, 'CA-2016-158834', 143, Decimal('157.92'), 5, Decimal('0.20'), Decimal('17.77'))
# (153, 'CA-2016-158834', 144, Decimal('203.18'), 2, Decimal('0.20'), Decimal('15.24'))
# (154, 'CA-2015-124919', 145, Decimal('58.38'), 7, Decimal('0.00'), Decimal('26.27'))
# (155, 'CA-2015-124919', 146, Decimal('105.52'), 4, Decimal('0.00'), Decimal('48.54'))
# (156, 'CA-2015-124919', 147, Decimal('80.88'), 6, Decimal('0.00'), Decimal('21.03'))
# (157, 'CA-2015-118948', 148, Decimal('6.63'), 3, Decimal('0.00'), Decimal('1.79'))
# (158, 'CA-2014-104269', 120, Decimal('457.57'), 2, Decimal('0.20'), Decimal('51.48'))
# (159, 'CA-2016-114104', 149, Decimal('14.62'), 2, Decimal('0.00'), Decimal('6.87'))
# (160, 'CA-2016-114104', 150, Decimal('944.93'), 7, Decimal('0.00'), Decimal('236.23'))
# (161, 'CA-2016-162733', 151, Decimal('5.98'), 1, Decimal('0.00'), Decimal('2.69'))
# (162, 'CA-2015-119697', 152, Decimal('54.38'), 2, Decimal('0.20'), Decimal('1.36'))
# (163, 'CA-2016-154508', 153, Decimal('28.40'), 5, Decimal('0.00'), Decimal('13.35'))
# (164, 'CA-2016-113817', 154, Decimal('27.68'), 2, Decimal('0.20'), Decimal('9.69'))
# (165, 'CA-2014-139892', 155, Decimal('9.94'), 3, Decimal('0.20'), Decimal('2.73'))
# (166, 'CA-2014-139892', 156, Decimal('8159.95'), 8, Decimal('0.40'), Decimal('-1359.99'))
# (167, 'CA-2014-139892', 157, Decimal('275.93'), 3, Decimal('0.20'), Decimal('-58.63'))
# (168, 'CA-2014-139892', 158, Decimal('1740.06'), 9, Decimal('0.30'), Decimal('-24.86'))
# (169, 'CA-2014-139892', 159, Decimal('32.06'), 6, Decimal('0.20'), Decimal('6.81'))
# (170, 'CA-2014-139892', 160, Decimal('177.98'), 5, Decimal('0.80'), Decimal('-453.85'))
# (171, 'CA-2014-139892', 161, Decimal('143.98'), 3, Decimal('0.20'), Decimal('9.00'))
# (172, 'CA-2014-118962', 162, Decimal('20.94'), 3, Decimal('0.00'), Decimal('9.84'))
# (173, 'CA-2014-118962', 163, Decimal('110.96'), 2, Decimal('0.00'), Decimal('53.26'))
# (174, 'CA-2014-118962', 164, Decimal('340.14'), 7, Decimal('0.20'), Decimal('21.26'))
# (175, 'US-2014-100853', 165, Decimal('52.45'), 2, Decimal('0.80'), Decimal('-131.12'))
# (176, 'US-2014-100853', 166, Decimal('20.16'), 4, Decimal('0.20'), Decimal('6.55'))
# (177, 'US-2017-152366', 167, Decimal('97.26'), 4, Decimal('0.80'), Decimal('-243.16'))
# (178, 'US-2015-101511', 168, Decimal('396.80'), 7, Decimal('0.30'), Decimal('-11.34'))
# (179, 'US-2015-101511', 169, Decimal('15.88'), 5, Decimal('0.20'), Decimal('-3.77'))
# (180, 'CA-2015-137225', 170, Decimal('3.28'), 1, Decimal('0.00'), Decimal('1.41'))
# (181, 'CA-2014-166191', 171, Decimal('24.82'), 2, Decimal('0.20'), Decimal('1.86'))
# (182, 'CA-2014-166191', 172, Decimal('408.74'), 7, Decimal('0.20'), Decimal('76.64'))
# (183, 'CA-2014-158274', 173, Decimal('503.96'), 4, Decimal('0.00'), Decimal('131.03'))
# (184, 'CA-2014-158274', 174, Decimal('149.95'), 5, Decimal('0.00'), Decimal('41.99'))
# (185, 'CA-2014-158274', 175, Decimal('29.00'), 2, Decimal('0.00'), Decimal('7.25'))
# (186, 'CA-2016-105018', 176, Decimal('7.16'), 2, Decimal('0.00'), Decimal('3.44'))
# (187, 'CA-2014-123260', 177, Decimal('176.80'), 8, Decimal('0.00'), Decimal('22.98'))
# (188, 'CA-2016-157000', 178, Decimal('37.22'), 3, Decimal('0.20'), Decimal('3.72'))
# (189, 'CA-2016-157000', 145, Decimal('20.02'), 3, Decimal('0.20'), Decimal('6.26'))
# (190, 'CA-2015-102281', 179, Decimal('899.14'), 4, Decimal('0.20'), Decimal('112.39'))
# (191, 'CA-2015-102281', 180, Decimal('71.76'), 6, Decimal('0.00'), Decimal('20.09'))
# (192, 'CA-2015-102281', 181, Decimal('51.84'), 8, Decimal('0.00'), Decimal('24.88'))
# (193, 'CA-2015-102281', 37, Decimal('626.35'), 3, Decimal('0.20'), Decimal('46.98'))
# (194, 'CA-2015-102281', 182, Decimal('19.90'), 5, Decimal('0.00'), Decimal('6.57'))
# (195, 'CA-2015-131457', 29, Decimal('14.28'), 7, Decimal('0.00'), Decimal('6.71'))
# (196, 'CA-2014-140004', 183, Decimal('7.41'), 2, Decimal('0.20'), Decimal('1.20'))
# (197, 'CA-2014-140004', 184, Decimal('6.05'), 3, Decimal('0.20'), Decimal('1.59'))
# (198, 'CA-2017-107720', 185, Decimal('46.26'), 3, Decimal('0.00'), Decimal('12.03'))
# (199, 'US-2017-124303', 186, Decimal('2.95'), 2, Decimal('0.70'), Decimal('-2.26'))
# (200, 'US-2017-124303', 187, Decimal('16.06'), 3, Decimal('0.20'), Decimal('5.82'))
# (201, 'CA-2017-105074', 188, Decimal('21.74'), 3, Decimal('0.20'), Decimal('6.80'))
# (202, 'CA-2014-133690', 189, Decimal('218.75'), 2, Decimal('0.50'), Decimal('-161.88'))
# (203, 'CA-2014-133690', 190, Decimal('2.60'), 1, Decimal('0.20'), Decimal('0.29'))
# (204, 'US-2017-116701', 191, Decimal('66.28'), 2, Decimal('0.80'), Decimal('-178.97'))
# (205, 'CA-2017-126382', 192, Decimal('35.17'), 7, Decimal('0.20'), Decimal('9.67'))
# (206, 'CA-2017-108329', 193, Decimal('444.77'), 4, Decimal('0.20'), Decimal('44.48'))
# (207, 'CA-2017-135860', 194, Decimal('83.92'), 4, Decimal('0.00'), Decimal('5.87'))
# (208, 'CA-2017-135860', 195, Decimal('131.98'), 2, Decimal('0.00'), Decimal('35.63'))
# (209, 'CA-2017-135860', 122, Decimal('15.92'), 4, Decimal('0.00'), Decimal('7.48'))
# (210, 'CA-2017-135860', 196, Decimal('52.29'), 9, Decimal('0.00'), Decimal('16.21'))
# (211, 'CA-2017-135860', 197, Decimal('91.99'), 1, Decimal('0.00'), Decimal('3.68'))
# (212, 'CA-2015-101007', 198, Decimal('20.80'), 2, Decimal('0.20'), Decimal('6.50'))
# (213, 'CA-2015-146262', 199, Decimal('23.68'), 2, Decimal('0.20'), Decimal('8.88'))
# (214, 'CA-2015-146262', 200, Decimal('452.45'), 5, Decimal('0.50'), Decimal('-244.32'))
# (215, 'CA-2015-146262', 104, Decimal('62.98'), 3, Decimal('0.40'), Decimal('-14.70'))
# (216, 'CA-2015-146262', 201, Decimal('1188.00'), 9, Decimal('0.70'), Decimal('-950.40'))
# (217, 'CA-2015-146262', 202, Decimal('89.58'), 2, Decimal('0.20'), Decimal('4.48'))
# (218, 'CA-2016-130162', 178, Decimal('93.06'), 6, Decimal('0.00'), Decimal('26.06'))
# (219, 'CA-2016-130162', 203, Decimal('302.38'), 3, Decimal('0.20'), Decimal('22.68'))
# (220, 'CA-2015-169397', 204, Decimal('5.58'), 2, Decimal('0.20'), Decimal('1.81'))
# (221, 'CA-2015-169397', 205, Decimal('22.70'), 6, Decimal('0.20'), Decimal('8.23'))
# (222, 'CA-2015-169397', 91, Decimal('19.78'), 4, Decimal('0.70'), Decimal('-13.84'))
# (223, 'CA-2015-169397', 206, Decimal('72.70'), 4, Decimal('0.20'), Decimal('19.08'))
# (224, 'CA-2015-169397', 207, Decimal('479.99'), 4, Decimal('0.70'), Decimal('-383.99'))
# (225, 'CA-2015-169397', 208, Decimal('27.17'), 2, Decimal('0.20'), Decimal('2.72'))
# (226, 'CA-2015-163055', 209, Decimal('2.20'), 1, Decimal('0.00'), Decimal('0.97'))
# (227, 'CA-2015-163055', 210, Decimal('622.45'), 5, Decimal('0.00'), Decimal('136.94'))
# (228, 'CA-2015-163055', 211, Decimal('21.98'), 1, Decimal('0.00'), Decimal('0.22'))
# (229, 'US-2015-145436', 212, Decimal('161.57'), 2, Decimal('0.20'), Decimal('-28.27'))
# (230, 'US-2015-145436', 213, Decimal('389.70'), 8, Decimal('0.20'), Decimal('43.84'))
# (231, 'US-2014-156216', 214, Decimal('18.65'), 7, Decimal('0.70'), Decimal('-12.43'))
# (232, 'US-2017-100930', 215, Decimal('233.86'), 2, Decimal('0.45'), Decimal('-102.05'))
# (233, 'US-2017-100930', 216, Decimal('620.61'), 3, Decimal('0.45'), Decimal('-248.25'))
# (234, 'US-2017-100930', 214, Decimal('5.33'), 2, Decimal('0.70'), Decimal('-3.55'))
# (235, 'US-2017-100930', 217, Decimal('258.07'), 3, Decimal('0.20'), Decimal('0.00'))
# (236, 'US-2017-100930', 218, Decimal('617.98'), 3, Decimal('0.20'), Decimal('-7.72'))
# (237, 'CA-2017-160514', 219, Decimal('10.56'), 2, Decimal('0.00'), Decimal('4.75'))
# (238, 'CA-2016-157749', 220, Decimal('25.92'), 5, Decimal('0.20'), Decimal('9.40'))
# (239, 'CA-2016-157749', 221, Decimal('419.68'), 5, Decimal('0.60'), Decimal('-356.73'))
# (240, 'CA-2016-157749', 222, Decimal('11.69'), 3, Decimal('0.60'), Decimal('-4.68'))
# (241, 'CA-2016-157749', 223, Decimal('31.98'), 2, Decimal('0.20'), Decimal('11.19'))
# (242, 'CA-2016-157749', 224, Decimal('177.22'), 5, Decimal('0.50'), Decimal('-120.51'))
# (243, 'CA-2016-157749', 225, Decimal('4.04'), 3, Decimal('0.60'), Decimal('-2.83'))
# (244, 'CA-2016-157749', 183, Decimal('7.41'), 2, Decimal('0.20'), Decimal('1.20'))
# (245, 'CA-2014-131926', 120, Decimal('2001.86'), 7, Decimal('0.00'), Decimal('580.54'))
# (246, 'CA-2014-131926', 226, Decimal('166.72'), 2, Decimal('0.00'), Decimal('41.68'))
# (247, 'CA-2014-131926', 227, Decimal('47.88'), 6, Decimal('0.00'), Decimal('23.94'))
# (248, 'CA-2014-131926', 228, Decimal('1503.25'), 5, Decimal('0.00'), Decimal('496.07'))
# (249, 'CA-2014-131926', 181, Decimal('25.92'), 4, Decimal('0.00'), Decimal('12.44'))
# (250, 'CA-2016-154739', 229, Decimal('321.57'), 2, Decimal('0.20'), Decimal('28.14'))
# (251, 'CA-2016-145625', 230, Decimal('7.61'), 1, Decimal('0.00'), Decimal('3.58'))
# (252, 'CA-2016-145625', 218, Decimal('3347.37'), 13, Decimal('0.00'), Decimal('636.00'))
# (253, 'CA-2016-146941', 231, Decimal('80.58'), 6, Decimal('0.00'), Decimal('22.56'))
# (254, 'CA-2016-146941', 232, Decimal('361.92'), 4, Decimal('0.00'), Decimal('162.86'))
# (255, 'US-2015-159982', 225, Decimal('12.13'), 9, Decimal('0.60'), Decimal('-8.49'))
# (256, 'US-2015-159982', 233, Decimal('82.37'), 2, Decimal('0.20'), Decimal('-19.56'))
# (257, 'US-2015-159982', 147, Decimal('53.92'), 5, Decimal('0.20'), Decimal('4.04'))
# (258, 'US-2015-159982', 234, Decimal('647.90'), 6, Decimal('0.20'), Decimal('56.69'))
# (259, 'CA-2017-163139', 235, Decimal('20.37'), 3, Decimal('0.00'), Decimal('6.93'))
# (260, 'CA-2017-163139', 236, Decimal('221.55'), 3, Decimal('0.00'), Decimal('6.65'))
# (261, 'CA-2017-163139', 237, Decimal('17.52'), 5, Decimal('0.20'), Decimal('6.13'))
# (262, 'US-2017-155299', 238, Decimal('1.62'), 2, Decimal('0.80'), Decimal('-4.47'))
# (263, 'US-2014-106992', 156, Decimal('3059.98'), 3, Decimal('0.40'), Decimal('-510.00'))
# (264, 'US-2014-106992', 239, Decimal('2519.96'), 7, Decimal('0.40'), Decimal('-252.00'))
# (265, 'CA-2016-125318', 240, Decimal('328.22'), 4, Decimal('0.20'), Decimal('28.72'))
# (266, 'CA-2015-155040', 241, Decimal('79.90'), 2, Decimal('0.00'), Decimal('35.16'))
# (267, 'CA-2017-136826', 242, Decimal('14.02'), 3, Decimal('0.20'), Decimal('4.73'))
# (268, 'CA-2016-111010', 243, Decimal('7.56'), 6, Decimal('0.00'), Decimal('0.30'))
# (269, 'US-2017-145366', 244, Decimal('37.21'), 1, Decimal('0.20'), Decimal('-7.44'))
# (270, 'US-2017-145366', 245, Decimal('57.58'), 3, Decimal('0.20'), Decimal('21.59'))
# (271, 'CA-2017-163979', 246, Decimal('725.84'), 4, Decimal('0.00'), Decimal('210.49'))
# (272, 'CA-2015-155334', 247, Decimal('209.93'), 7, Decimal('0.00'), Decimal('92.37'))
# (273, 'CA-2015-155334', 248, Decimal('5.28'), 3, Decimal('0.00'), Decimal('2.32'))
# (274, 'CA-2015-155334', 249, Decimal('10.92'), 3, Decimal('0.20'), Decimal('4.10'))
# (275, 'CA-2017-118136', 250, Decimal('8.82'), 2, Decimal('0.00'), Decimal('4.06'))
# (276, 'CA-2017-118136', 251, Decimal('5.98'), 1, Decimal('0.00'), Decimal('1.55'))
# (277, 'CA-2017-132976', 252, Decimal('11.65'), 2, Decimal('0.20'), Decimal('4.08'))
# (278, 'CA-2017-132976', 253, Decimal('18.18'), 4, Decimal('0.20'), Decimal('5.91'))
# (279, 'CA-2017-132976', 254, Decimal('59.71'), 6, Decimal('0.20'), Decimal('5.97'))
# (280, 'CA-2017-132976', 255, Decimal('24.84'), 3, Decimal('0.20'), Decimal('8.69'))
# (281, 'US-2015-161991', 256, Decimal('2.08'), 5, Decimal('0.80'), Decimal('-3.43'))
# (282, 'US-2015-161991', 257, Decimal('1114.40'), 7, Decimal('0.20'), Decimal('376.11'))
# (283, 'CA-2015-130890', 258, Decimal('1038.84'), 5, Decimal('0.20'), Decimal('51.94'))
# (284, 'CA-2015-130883', 259, Decimal('141.76'), 5, Decimal('0.20'), Decimal('47.84'))
# (285, 'CA-2015-130883', 260, Decimal('239.80'), 5, Decimal('0.20'), Decimal('47.96'))
# (286, 'CA-2015-130883', 261, Decimal('31.10'), 6, Decimal('0.20'), Decimal('10.89'))
# (287, 'CA-2016-112697', 262, Decimal('254.06'), 7, Decimal('0.70'), Decimal('-169.37'))
# (288, 'CA-2016-112697', 167, Decimal('194.53'), 2, Decimal('0.20'), Decimal('24.32'))
# (289, 'CA-2016-112697', 263, Decimal('961.48'), 5, Decimal('0.20'), Decimal('-204.31'))
# (290, 'CA-2016-110772', 264, Decimal('19.10'), 7, Decimal('0.20'), Decimal('6.68'))
# (291, 'CA-2016-110772', 265, Decimal('18.50'), 8, Decimal('0.20'), Decimal('6.24'))
# (292, 'CA-2016-110772', 266, Decimal('255.98'), 2, Decimal('0.20'), Decimal('54.40'))
# (293, 'CA-2016-110772', 267, Decimal('86.97'), 3, Decimal('0.50'), Decimal('-48.70'))
# (294, 'CA-2014-111451', 268, Decimal('300.42'), 8, Decimal('0.20'), Decimal('78.86'))
# (295, 'CA-2014-111451', 269, Decimal('230.35'), 3, Decimal('0.20'), Decimal('20.16'))
# (296, 'CA-2014-111451', 270, Decimal('218.35'), 3, Decimal('0.20'), Decimal('-24.56'))
# (297, 'CA-2014-111451', 271, Decimal('78.60'), 5, Decimal('0.70'), Decimal('-62.88'))
# (298, 'CA-2014-111451', 272, Decimal('27.55'), 3, Decimal('0.20'), Decimal('9.30'))
# (299, 'CA-2016-142545', 273, Decimal('32.40'), 5, Decimal('0.00'), Decimal('15.55'))
# (300, 'CA-2016-142545', 274, Decimal('1082.48'), 8, Decimal('0.00'), Decimal('10.82'))
# (301, 'CA-2016-142545', 275, Decimal('56.91'), 3, Decimal('0.00'), Decimal('27.32'))
# (302, 'CA-2016-142545', 276, Decimal('77.60'), 4, Decimal('0.00'), Decimal('38.02'))
# (303, 'CA-2016-142545', 277, Decimal('14.28'), 1, Decimal('0.00'), Decimal('6.57'))
# (304, 'US-2017-152380', 278, Decimal('219.08'), 3, Decimal('0.50'), Decimal('-131.44'))
# (305, 'CA-2015-144253', 279, Decimal('26.80'), 2, Decimal('0.00'), Decimal('12.86'))
# (306, 'CA-2014-130960', 280, Decimal('9.84'), 3, Decimal('0.00'), Decimal('2.85'))
# (307, 'CA-2014-111003', 281, Decimal('45.48'), 3, Decimal('0.00'), Decimal('20.92'))
# (308, 'CA-2014-111003', 282, Decimal('289.20'), 6, Decimal('0.00'), Decimal('83.87'))
# (309, 'CA-2017-126774', 283, Decimal('4.89'), 1, Decimal('0.00'), Decimal('2.00'))
# (310, 'CA-2016-142902', 284, Decimal('15.14'), 4, Decimal('0.20'), Decimal('3.59'))
# (311, 'CA-2016-142902', 285, Decimal('466.77'), 2, Decimal('0.20'), Decimal('52.51'))
# (312, 'CA-2016-142902', 286, Decimal('15.23'), 1, Decimal('0.20'), Decimal('1.71'))
# (313, 'CA-2016-142902', 287, Decimal('6.26'), 3, Decimal('0.20'), Decimal('2.04'))
# (314, 'CA-2014-120887', 288, Decimal('87.54'), 3, Decimal('0.00'), Decimal('37.64'))
# (315, 'CA-2014-167850', 289, Decimal('178.38'), 2, Decimal('0.20'), Decimal('22.30'))
# (316, 'CA-2014-167850', 290, Decimal('15.55'), 3, Decimal('0.20'), Decimal('5.44'))
# (317, 'CA-2014-164259', 291, Decimal('99.14'), 4, Decimal('0.20'), Decimal('8.67'))
# (318, 'CA-2014-164973', 292, Decimal('135.88'), 1, Decimal('0.10'), Decimal('24.16'))
# (319, 'CA-2014-164973', 293, Decimal('3991.98'), 2, Decimal('0.00'), Decimal('1995.99'))
# (320, 'CA-2014-164973', 40, Decimal('275.94'), 6, Decimal('0.00'), Decimal('80.02'))
# (321, 'CA-2014-164973', 294, Decimal('360.00'), 4, Decimal('0.00'), Decimal('129.60'))
# (322, 'CA-2014-164973', 123, Decimal('43.57'), 1, Decimal('0.00'), Decimal('13.07'))
# (323, 'CA-2014-156601', 295, Decimal('7.16'), 2, Decimal('0.00'), Decimal('3.58'))
# (324, 'CA-2016-162138', 271, Decimal('251.52'), 6, Decimal('0.20'), Decimal('81.74'))
# (325, 'CA-2016-162138', 296, Decimal('99.99'), 1, Decimal('0.00'), Decimal('35.00'))
# (326, 'CA-2017-153339', 297, Decimal('15.99'), 1, Decimal('0.20'), Decimal('1.00'))
# (327, 'US-2016-141544', 298, Decimal('290.90'), 3, Decimal('0.40'), Decimal('-67.88'))
# (328, 'US-2016-141544', 299, Decimal('54.22'), 2, Decimal('0.20'), Decimal('3.39'))
# (329, 'US-2016-141544', 300, Decimal('786.74'), 4, Decimal('0.30'), Decimal('-258.50'))
# (330, 'US-2016-141544', 301, Decimal('100.24'), 10, Decimal('0.20'), Decimal('33.83'))
# (331, 'US-2016-141544', 302, Decimal('37.76'), 6, Decimal('0.70'), Decimal('-27.69'))
# (332, 'US-2016-150147', 303, Decimal('82.80'), 2, Decimal('0.40'), Decimal('-20.70'))
# (333, 'US-2016-150147', 304, Decimal('20.72'), 2, Decimal('0.70'), Decimal('-13.82'))
# (334, 'US-2016-150147', 305, Decimal('4.90'), 3, Decimal('0.70'), Decimal('-3.43'))
# (335, 'CA-2015-137946', 306, Decimal('4.75'), 1, Decimal('0.20'), Decimal('1.60'))
# (336, 'CA-2015-137946', 307, Decimal('959.98'), 2, Decimal('0.20'), Decimal('335.99'))
# (337, 'CA-2015-137946', 308, Decimal('14.37'), 4, Decimal('0.20'), Decimal('4.49'))
# (338, 'CA-2014-129924', 309, Decimal('7.71'), 2, Decimal('0.20'), Decimal('2.80'))
# (339, 'CA-2014-129924', 310, Decimal('698.35'), 3, Decimal('0.20'), Decimal('-17.46'))
# (340, 'CA-2015-128167', 311, Decimal('4.96'), 4, Decimal('0.00'), Decimal('2.33'))
# (341, 'CA-2014-122336', 312, Decimal('17.86'), 4, Decimal('0.20'), Decimal('1.12'))
# (342, 'CA-2014-122336', 13, Decimal('509.97'), 10, Decimal('0.70'), Decimal('-407.98'))
# (343, 'CA-2014-122336', 128, Decimal('30.99'), 13, Decimal('0.20'), Decimal('10.07'))
# (344, 'CA-2014-122336', 313, Decimal('71.93'), 12, Decimal('0.40'), Decimal('8.39'))
# (345, 'US-2015-120712', 17, Decimal('88.80'), 4, Decimal('0.20'), Decimal('-2.22'))
# (346, 'CA-2017-169901', 126, Decimal('47.98'), 3, Decimal('0.20'), Decimal('4.80'))
# (347, 'CA-2017-134306', 184, Decimal('7.56'), 3, Decimal('0.00'), Decimal('3.10'))
# (348, 'CA-2017-134306', 33, Decimal('24.56'), 2, Decimal('0.00'), Decimal('11.54'))
# (349, 'CA-2017-134306', 314, Decimal('12.96'), 2, Decimal('0.00'), Decimal('4.15'))
# (350, 'CA-2016-129714', 235, Decimal('6.79'), 1, Decimal('0.00'), Decimal('2.31'))
# (351, 'CA-2016-129714', 315, Decimal('24.56'), 2, Decimal('0.00'), Decimal('11.54'))
# (352, 'CA-2016-129714', 316, Decimal('3.05'), 1, Decimal('0.20'), Decimal('1.07'))
# (353, 'CA-2016-129714', 315, Decimal('49.12'), 4, Decimal('0.00'), Decimal('23.09'))
# (354, 'CA-2016-129714', 317, Decimal('4355.17'), 4, Decimal('0.20'), Decimal('1415.43'))
# (355, 'CA-2016-138520', 318, Decimal('388.70'), 6, Decimal('0.20'), Decimal('-4.86'))
# (356, 'CA-2016-138520', 319, Decimal('8.26'), 2, Decimal('0.00'), Decimal('3.80'))
# (357, 'CA-2016-138520', 320, Decimal('17.04'), 4, Decimal('0.00'), Decimal('6.99'))
# (358, 'CA-2016-138520', 321, Decimal('34.40'), 5, Decimal('0.00'), Decimal('15.82'))
# (359, 'CA-2016-130001', 188, Decimal('36.24'), 5, Decimal('0.20'), Decimal('11.32'))
# (360, 'CA-2017-155698', 322, Decimal('647.84'), 8, Decimal('0.00'), Decimal('168.44'))
# (361, 'CA-2017-155698', 323, Decimal('20.70'), 2, Decimal('0.00'), Decimal('9.94'))
# (362, 'CA-2017-144904', 323, Decimal('20.70'), 2, Decimal('0.00'), Decimal('9.94'))
# (363, 'CA-2017-144904', 324, Decimal('488.65'), 3, Decimal('0.10'), Decimal('86.87'))
# (364, 'CA-2017-144904', 325, Decimal('5.56'), 2, Decimal('0.00'), Decimal('1.45'))
# (365, 'CA-2017-144904', 326, Decimal('47.12'), 8, Decimal('0.00'), Decimal('20.73'))
# (366, 'CA-2014-123344', 45, Decimal('211.96'), 4, Decimal('0.00'), Decimal('8.48'))
# (367, 'CA-2016-155516', 327, Decimal('23.20'), 4, Decimal('0.00'), Decimal('10.44'))
# (368, 'CA-2016-155516', 328, Decimal('7.36'), 2, Decimal('0.00'), Decimal('0.15'))
# (369, 'CA-2016-155516', 329, Decimal('104.79'), 7, Decimal('0.00'), Decimal('29.34'))
# (370, 'CA-2016-155516', 37, Decimal('1043.92'), 4, Decimal('0.00'), Decimal('271.42'))
# (371, 'CA-2017-104745', 330, Decimal('25.92'), 5, Decimal('0.20'), Decimal('9.40'))
# (372, 'CA-2017-104745', 331, Decimal('53.42'), 3, Decimal('0.20'), Decimal('4.67'))
# (373, 'US-2014-119137', 305, Decimal('8.16'), 5, Decimal('0.70'), Decimal('-5.71'))
# (374, 'US-2014-119137', 332, Decimal('1023.94'), 8, Decimal('0.20'), Decimal('179.19'))
# (375, 'US-2014-119137', 333, Decimal('9.24'), 1, Decimal('0.20'), Decimal('0.92'))
# (376, 'US-2014-119137', 334, Decimal('479.04'), 10, Decimal('0.20'), Decimal('-29.94'))
# (377, 'US-2016-134656', 335, Decimal('99.14'), 4, Decimal('0.20'), Decimal('30.98'))
# (378, 'US-2017-134481', 336, Decimal('1488.42'), 7, Decimal('0.30'), Decimal('-297.68'))
# (379, 'CA-2015-130792', 337, Decimal('8.65'), 3, Decimal('0.80'), Decimal('-20.33'))
# (380, 'CA-2015-130792', 338, Decimal('23.83'), 3, Decimal('0.20'), Decimal('2.68'))
# (381, 'CA-2015-130792', 339, Decimal('12.18'), 4, Decimal('0.80'), Decimal('-18.87'))
# (382, 'CA-2016-134775', 340, Decimal('50.96'), 7, Decimal('0.00'), Decimal('25.48'))
# (383, 'CA-2016-134775', 341, Decimal('49.54'), 3, Decimal('0.20'), Decimal('17.34'))
# (384, 'CA-2015-125395', 342, Decimal('41.90'), 2, Decimal('0.00'), Decimal('8.80'))
# (385, 'US-2015-168935', 343, Decimal('375.46'), 3, Decimal('0.45'), Decimal('-157.01'))
# (386, 'US-2015-168935', 344, Decimal('83.98'), 3, Decimal('0.20'), Decimal('-1.05'))
# (387, 'CA-2015-122756', 345, Decimal('482.34'), 4, Decimal('0.70'), Decimal('-337.64'))
# (388, 'CA-2015-122756', 346, Decimal('2.96'), 1, Decimal('0.20'), Decimal('0.78'))
# (389, 'CA-2014-115973', 347, Decimal('2.62'), 1, Decimal('0.20'), Decimal('0.43'))
# (390, 'CA-2017-101798', 348, Decimal('23.36'), 4, Decimal('0.20'), Decimal('7.88'))
# (391, 'CA-2017-101798', 84, Decimal('39.98'), 2, Decimal('0.00'), Decimal('13.59'))
# (392, 'US-2014-135972', 349, Decimal('246.38'), 2, Decimal('0.20'), Decimal('27.72'))
# (393, 'US-2014-135972', 350, Decimal('1799.97'), 3, Decimal('0.00'), Decimal('701.99'))
# (394, 'US-2014-134971', 351, Decimal('12.46'), 3, Decimal('0.80'), Decimal('-20.56'))
# (395, 'CA-2017-102946', 352, Decimal('75.79'), 3, Decimal('0.20'), Decimal('25.58'))
# (396, 'CA-2017-165603', 353, Decimal('49.96'), 2, Decimal('0.00'), Decimal('9.49'))
# (397, 'CA-2017-165603', 354, Decimal('12.96'), 2, Decimal('0.00'), Decimal('6.22'))
# (398, 'CA-2015-122259', 355, Decimal('70.12'), 4, Decimal('0.00'), Decimal('21.04'))
# (399, 'CA-2016-108987', 356, Decimal('35.95'), 3, Decimal('0.20'), Decimal('3.60'))
# (400, 'CA-2016-108987', 26, Decimal('2396.27'), 4, Decimal('0.32'), Decimal('-317.15'))
# (401, 'CA-2016-108987', 357, Decimal('131.14'), 4, Decimal('0.20'), Decimal('-32.78'))
# (402, 'CA-2016-108987', 358, Decimal('57.58'), 2, Decimal('0.20'), Decimal('0.72'))
# (403, 'CA-2014-113166', 359, Decimal('9.57'), 2, Decimal('0.20'), Decimal('3.47'))
# (404, 'CA-2014-155208', 360, Decimal('39.07'), 6, Decimal('0.20'), Decimal('9.77'))
# (405, 'CA-2017-117933', 361, Decimal('35.91'), 3, Decimal('0.00'), Decimal('9.70'))
# (406, 'CA-2017-117457', 358, Decimal('179.95'), 5, Decimal('0.00'), Decimal('37.79'))
# (407, 'CA-2017-117457', 362, Decimal('1199.98'), 3, Decimal('0.20'), Decimal('434.99'))
# (408, 'CA-2017-117457', 363, Decimal('27.15'), 5, Decimal('0.00'), Decimal('13.30'))
# (409, 'CA-2017-117457', 364, Decimal('1004.02'), 7, Decimal('0.20'), Decimal('-112.95'))
# (410, 'CA-2017-117457', 365, Decimal('9.68'), 1, Decimal('0.00'), Decimal('4.65'))
# (411, 'CA-2017-117457', 366, Decimal('28.35'), 9, Decimal('0.00'), Decimal('13.61'))
# (412, 'CA-2017-117457', 367, Decimal('55.98'), 1, Decimal('0.00'), Decimal('27.43'))
# (413, 'CA-2017-117457', 368, Decimal('1336.83'), 13, Decimal('0.15'), Decimal('31.45'))
# (414, 'CA-2017-117457', 369, Decimal('113.57'), 2, Decimal('0.20'), Decimal('-18.45'))
# (415, 'CA-2017-142636', 370, Decimal('139.86'), 7, Decimal('0.00'), Decimal('65.73'))
# (416, 'CA-2017-142636', 269, Decimal('307.14'), 4, Decimal('0.20'), Decimal('26.87'))
# (417, 'CA-2017-122105', 371, Decimal('95.92'), 8, Decimal('0.00'), Decimal('25.90'))
# (418, 'CA-2016-148796', 372, Decimal('383.80'), 5, Decimal('0.20'), Decimal('38.38'))
# (419, 'CA-2017-154816', 373, Decimal('5.78'), 1, Decimal('0.00'), Decimal('2.83'))
# (420, 'CA-2017-110478', 374, Decimal('9.32'), 4, Decimal('0.00'), Decimal('2.70'))
# (421, 'CA-2017-110478', 375, Decimal('15.25'), 1, Decimal('0.00'), Decimal('7.02'))
# (422, 'CA-2014-142048', 376, Decimal('196.75'), 6, Decimal('0.20'), Decimal('56.57'))
# (423, 'CA-2017-125388', 377, Decimal('56.56'), 4, Decimal('0.00'), Decimal('14.71'))
# (424, 'CA-2017-125388', 378, Decimal('32.70'), 3, Decimal('0.00'), Decimal('8.50'))
# (425, 'CA-2017-155705', 379, Decimal('866.40'), 4, Decimal('0.00'), Decimal('225.26'))
# (426, 'CA-2017-149160', 380, Decimal('28.40'), 2, Decimal('0.00'), Decimal('11.08'))
# (427, 'CA-2017-149160', 381, Decimal('287.92'), 8, Decimal('0.00'), Decimal('138.20'))
# (428, 'CA-2014-101476', 382, Decimal('69.99'), 1, Decimal('0.00'), Decimal('30.10'))
# (429, 'CA-2017-152275', 383, Decimal('6.67'), 6, Decimal('0.20'), Decimal('0.50'))
# (430, 'US-2016-123750', 384, Decimal('189.59'), 2, Decimal('0.70'), Decimal('-145.35'))
# (431, 'US-2016-123750', 172, Decimal('408.74'), 7, Decimal('0.20'), Decimal('76.64'))
# (432, 'US-2016-123750', 172, Decimal('291.96'), 5, Decimal('0.20'), Decimal('54.74'))
# (433, 'US-2016-123750', 385, Decimal('4.77'), 2, Decimal('0.20'), Decimal('-0.77'))
# (434, 'CA-2016-127369', 386, Decimal('714.30'), 5, Decimal('0.00'), Decimal('207.15'))
# (435, 'US-2014-150574', 387, Decimal('4.81'), 2, Decimal('0.70'), Decimal('-3.69'))
# (436, 'US-2014-150574', 388, Decimal('247.80'), 5, Decimal('0.20'), Decimal('-18.58'))
# (437, 'CA-2016-147375', 389, Decimal('1007.98'), 3, Decimal('0.30'), Decimal('43.20'))
# (438, 'CA-2016-147375', 367, Decimal('313.49'), 7, Decimal('0.20'), Decimal('113.64'))
# (439, 'CA-2017-130043', 390, Decimal('31.87'), 8, Decimal('0.20'), Decimal('11.55'))
# (440, 'CA-2017-157252', 391, Decimal('207.85'), 3, Decimal('0.10'), Decimal('2.31'))
# (441, 'CA-2016-115756', 392, Decimal('12.22'), 1, Decimal('0.00'), Decimal('3.67'))
# (442, 'CA-2016-115756', 393, Decimal('194.94'), 3, Decimal('0.00'), Decimal('23.39'))
# (443, 'CA-2016-115756', 394, Decimal('70.95'), 3, Decimal('0.00'), Decimal('20.58'))
# (444, 'CA-2016-115756', 395, Decimal('91.36'), 4, Decimal('0.00'), Decimal('42.03'))
# (445, 'CA-2016-115756', 396, Decimal('242.94'), 3, Decimal('0.00'), Decimal('29.15'))
# (446, 'CA-2016-115756', 397, Decimal('22.05'), 7, Decimal('0.00'), Decimal('10.58'))
# (447, 'CA-2017-154214', 398, Decimal('2.91'), 1, Decimal('0.00'), Decimal('1.37'))
# (448, 'CA-2016-166674', 399, Decimal('59.52'), 3, Decimal('0.00'), Decimal('15.48'))
# (449, 'CA-2016-166674', 400, Decimal('161.94'), 3, Decimal('0.00'), Decimal('9.72'))
# (450, 'CA-2016-166674', 401, Decimal('263.88'), 6, Decimal('0.00'), Decimal('71.25'))
# (451, 'CA-2016-166674', 402, Decimal('30.48'), 3, Decimal('0.00'), Decimal('7.92'))
# (452, 'CA-2016-166674', 403, Decimal('9.84'), 3, Decimal('0.00'), Decimal('2.85'))
# (453, 'CA-2016-166674', 404, Decimal('35.12'), 4, Decimal('0.00'), Decimal('9.13'))
# (454, 'CA-2017-147277', 10, Decimal('284.36'), 2, Decimal('0.40'), Decimal('-75.83'))
# (455, 'CA-2017-147277', 405, Decimal('665.41'), 2, Decimal('0.20'), Decimal('66.54'))
# (456, 'CA-2016-100153', 406, Decimal('63.88'), 4, Decimal('0.00'), Decimal('24.91'))
# (457, 'US-2014-110674', 407, Decimal('129.57'), 2, Decimal('0.20'), Decimal('-24.29'))
# (458, 'US-2016-157945', 408, Decimal('747.56'), 3, Decimal('0.30'), Decimal('-96.11'))
# (459, 'US-2016-157945', 409, Decimal('8.93'), 2, Decimal('0.20'), Decimal('3.35'))
# (460, 'CA-2015-109638', 410, Decimal('103.92'), 4, Decimal('0.00'), Decimal('36.37'))
# (461, 'CA-2015-109638', 411, Decimal('899.91'), 9, Decimal('0.00'), Decimal('377.96'))
# (462, 'CA-2015-109638', 412, Decimal('51.31'), 3, Decimal('0.20'), Decimal('18.60'))
# (463, 'CA-2016-109869', 326, Decimal('23.56'), 5, Decimal('0.20'), Decimal('7.07'))
# (464, 'CA-2016-109869', 413, Decimal('1272.63'), 6, Decimal('0.50'), Decimal('-814.48'))
# (465, 'CA-2016-109869', 414, Decimal('28.48'), 5, Decimal('0.70'), Decimal('-20.89'))
# (466, 'CA-2016-109869', 415, Decimal('185.38'), 2, Decimal('0.20'), Decimal('-34.76'))
# (467, 'CA-2016-109869', 416, Decimal('78.27'), 2, Decimal('0.20'), Decimal('5.87'))
# (468, 'US-2015-101399', 270, Decimal('254.74'), 7, Decimal('0.60'), Decimal('-312.06'))
# (469, 'CA-2017-154907', 417, Decimal('205.33'), 2, Decimal('0.32'), Decimal('-36.24'))
# (470, 'US-2016-100419', 418, Decimal('4.79'), 3, Decimal('0.80'), Decimal('-7.90'))
# (471, 'CA-2015-154144', 419, Decimal('55.48'), 1, Decimal('0.00'), Decimal('26.63'))
# (472, 'CA-2014-144666', 420, Decimal('340.92'), 3, Decimal('0.00'), Decimal('3.41'))
# (473, 'CA-2014-144666', 421, Decimal('222.67'), 2, Decimal('0.15'), Decimal('10.48'))
# (474, 'CA-2014-144666', 422, Decimal('703.97'), 4, Decimal('0.20'), Decimal('88.00'))
# (475, 'CA-2014-144666', 423, Decimal('92.52'), 6, Decimal('0.00'), Decimal('24.98'))
# (476, 'CA-2014-144666', 424, Decimal('62.65'), 7, Decimal('0.00'), Decimal('28.82'))
# (477, 'CA-2014-144666', 425, Decimal('94.85'), 5, Decimal('0.00'), Decimal('45.53'))
# (478, 'CA-2016-103891', 426, Decimal('95.76'), 6, Decimal('0.20'), Decimal('7.18'))
# (479, 'CA-2016-152632', 279, Decimal('40.20'), 3, Decimal('0.00'), Decimal('19.30'))
# (480, 'CA-2016-100790', 427, Decimal('14.70'), 5, Decimal('0.00'), Decimal('6.62'))
# (481, 'CA-2016-100790', 428, Decimal('704.25'), 5, Decimal('0.00'), Decimal('84.51'))
# (482, 'CA-2014-134677', 429, Decimal('9.09'), 3, Decimal('0.00'), Decimal('1.91'))
# (483, 'CA-2014-127691', 79, Decimal('5.96'), 2, Decimal('0.00'), Decimal('1.67'))
# (484, 'CA-2014-127691', 430, Decimal('159.98'), 2, Decimal('0.00'), Decimal('57.59'))
# (485, 'CA-2017-140963', 431, Decimal('29.60'), 2, Decimal('0.00'), Decimal('14.80'))
# (486, 'CA-2017-140963', 432, Decimal('514.16'), 5, Decimal('0.15'), Decimal('-30.24'))
# (487, 'CA-2017-140963', 433, Decimal('279.96'), 5, Decimal('0.20'), Decimal('17.50'))
# (488, 'CA-2014-154627', 434, Decimal('2735.95'), 6, Decimal('0.20'), Decimal('341.99'))
# (489, 'CA-2014-133753', 435, Decimal('7.99'), 1, Decimal('0.20'), Decimal('0.60'))
# (490, 'CA-2014-133753', 436, Decimal('63.98'), 2, Decimal('0.20'), Decimal('10.40'))
# (491, 'CA-2014-133753', 401, Decimal('70.37'), 2, Decimal('0.20'), Decimal('6.16'))
# (492, 'CA-2014-113362', 437, Decimal('449.15'), 5, Decimal('0.00'), Decimal('8.98'))
# (493, 'CA-2014-113362', 438, Decimal('11.07'), 3, Decimal('0.00'), Decimal('5.09'))
# (494, 'CA-2016-169166', 439, Decimal('93.98'), 2, Decimal('0.00'), Decimal('13.16'))
# (495, 'US-2016-120929', 440, Decimal('189.88'), 3, Decimal('0.40'), Decimal('-94.94'))
# (496, 'CA-2015-134782', 441, Decimal('105.42'), 2, Decimal('0.00'), Decimal('51.66'))
# (497, 'CA-2016-126158', 442, Decimal('119.62'), 8, Decimal('0.20'), Decimal('40.37'))
# (498, 'CA-2016-126158', 443, Decimal('255.76'), 4, Decimal('0.00'), Decimal('81.84'))
# (499, 'CA-2016-126158', 292, Decimal('241.57'), 2, Decimal('0.20'), Decimal('18.12'))
# (500, 'CA-2016-126158', 444, Decimal('69.30'), 9, Decimal('0.00'), Decimal('22.87'))
# (501, 'US-2016-105578', 445, Decimal('22.62'), 2, Decimal('0.70'), Decimal('-15.08'))
# (502, 'US-2016-105578', 446, Decimal('14.95'), 2, Decimal('0.70'), Decimal('-11.96'))
# (503, 'US-2016-105578', 447, Decimal('801.57'), 2, Decimal('0.20'), Decimal('50.10'))
# (504, 'US-2016-105578', 448, Decimal('2.38'), 3, Decimal('0.70'), Decimal('-1.90'))
# (505, 'US-2016-105578', 449, Decimal('32.79'), 1, Decimal('0.20'), Decimal('11.89'))
# (506, 'CA-2017-134978', 122, Decimal('15.92'), 5, Decimal('0.20'), Decimal('5.37'))
# (507, 'CA-2015-145352', 450, Decimal('2.74'), 1, Decimal('0.00'), Decimal('0.74'))
# (508, 'CA-2015-145352', 451, Decimal('8.34'), 3, Decimal('0.00'), Decimal('2.17'))
# (509, 'CA-2015-145352', 452, Decimal('46.74'), 3, Decimal('0.00'), Decimal('11.68'))
# (510, 'CA-2015-145352', 453, Decimal('6354.95'), 5, Decimal('0.00'), Decimal('3177.48'))
# (511, 'CA-2017-135307', 454, Decimal('126.30'), 3, Decimal('0.00'), Decimal('40.42'))
# (512, 'CA-2017-135307', 455, Decimal('38.04'), 2, Decimal('0.00'), Decimal('12.17'))
# (513, 'CA-2016-106341', 79, Decimal('7.15'), 3, Decimal('0.20'), Decimal('0.72'))
# (514, 'CA-2017-163405', 456, Decimal('6.63'), 3, Decimal('0.00'), Decimal('1.79'))
# (515, 'CA-2017-163405', 457, Decimal('5.88'), 2, Decimal('0.00'), Decimal('1.71'))
# (516, 'CA-2017-127432', 458, Decimal('2999.95'), 5, Decimal('0.00'), Decimal('1379.98'))
# (517, 'CA-2017-127432', 459, Decimal('51.45'), 3, Decimal('0.00'), Decimal('13.89'))
# (518, 'CA-2017-127432', 460, Decimal('11.96'), 2, Decimal('0.00'), Decimal('5.38'))
# (519, 'CA-2017-127432', 461, Decimal('1126.02'), 3, Decimal('0.00'), Decimal('56.30'))
# (520, 'CA-2015-157812', 43, Decimal('18.39'), 1, Decimal('0.20'), Decimal('5.29'))
# (521, 'CA-2015-157812', 462, Decimal('129.57'), 2, Decimal('0.20'), Decimal('-25.91'))
# (522, 'CA-2015-157812', 463, Decimal('14.11'), 9, Decimal('0.80'), Decimal('-21.17'))
# (523, 'CA-2017-145142', 440, Decimal('210.98'), 2, Decimal('0.00'), Decimal('21.10'))
# (524, 'US-2016-139486', 464, Decimal('55.18'), 3, Decimal('0.20'), Decimal('-12.41'))
# (525, 'US-2016-139486', 465, Decimal('66.26'), 2, Decimal('0.00'), Decimal('27.17'))
# (526, 'CA-2015-158792', 466, Decimal('22.20'), 5, Decimal('0.00'), Decimal('10.43'))
# (527, 'CA-2017-113558', 467, Decimal('683.95'), 3, Decimal('0.20'), Decimal('42.75'))
# (528, 'CA-2017-113558', 286, Decimal('45.70'), 3, Decimal('0.20'), Decimal('5.14'))
# (529, 'US-2015-138303', 468, Decimal('36.34'), 3, Decimal('0.20'), Decimal('-7.27'))
# (530, 'US-2015-138303', 469, Decimal('666.25'), 1, Decimal('0.20'), Decimal('-149.91'))
# (531, 'US-2015-138303', 470, Decimal('52.51'), 6, Decimal('0.20'), Decimal('19.69'))
# (532, 'CA-2015-102848', 471, Decimal('190.72'), 1, Decimal('0.20'), Decimal('11.92'))
# (533, 'US-2017-129441', 472, Decimal('47.94'), 3, Decimal('0.00'), Decimal('2.40'))
# (534, 'CA-2016-168753', 473, Decimal('979.95'), 5, Decimal('0.00'), Decimal('274.39'))
# (535, 'CA-2016-168753', 249, Decimal('22.75'), 5, Decimal('0.00'), Decimal('11.38'))
# (536, 'CA-2016-126613', 474, Decimal('16.77'), 2, Decimal('0.20'), Decimal('1.47'))
# (537, 'US-2017-122637', 475, Decimal('42.62'), 7, Decimal('0.80'), Decimal('-68.19'))
# (538, 'CA-2015-147851', 476, Decimal('10.75'), 4, Decimal('0.20'), Decimal('3.36'))
# (539, 'CA-2015-134894', 477, Decimal('152.94'), 3, Decimal('0.00'), Decimal('41.29'))
# (540, 'CA-2015-134894', 478, Decimal('283.92'), 4, Decimal('0.00'), Decimal('70.98'))
# (541, 'CA-2014-140795', 479, Decimal('468.90'), 6, Decimal('0.00'), Decimal('206.32'))
# (542, 'CA-2016-136924', 480, Decimal('380.86'), 8, Decimal('0.20'), Decimal('38.09'))
# (543, 'US-2015-120161', 437, Decimal('646.78'), 9, Decimal('0.20'), Decimal('-145.52'))
# (544, 'CA-2014-103849', 481, Decimal('58.11'), 2, Decimal('0.20'), Decimal('7.26'))
# (545, 'CA-2014-103849', 482, Decimal('100.79'), 1, Decimal('0.20'), Decimal('6.30'))
# (546, 'CA-2014-103849', 483, Decimal('66.11'), 4, Decimal('0.60'), Decimal('-84.29'))
# (547, 'CA-2017-162929', 484, Decimal('41.28'), 6, Decimal('0.20'), Decimal('13.93'))
# (548, 'CA-2017-162929', 485, Decimal('13.36'), 2, Decimal('0.00'), Decimal('6.41'))
# (549, 'CA-2015-113173', 54, Decimal('250.27'), 9, Decimal('0.20'), Decimal('15.64'))
# (550, 'CA-2015-113173', 92, Decimal('11.36'), 3, Decimal('0.80'), Decimal('-17.05'))
# (551, 'CA-2015-113173', 486, Decimal('8.72'), 5, Decimal('0.20'), Decimal('-1.74'))
# (552, 'CA-2016-136406', 487, Decimal('1121.57'), 2, Decimal('0.20'), Decimal('0.00'))
# (553, 'CA-2017-112774', 488, Decimal('34.50'), 1, Decimal('0.20'), Decimal('6.04'))
# (554, 'CA-2017-101945', 489, Decimal('10.82'), 3, Decimal('0.20'), Decimal('2.57'))
# (555, 'CA-2017-100650', 490, Decimal('1295.78'), 2, Decimal('0.00'), Decimal('310.99'))
# (556, 'CA-2014-155852', 491, Decimal('19.46'), 4, Decimal('0.20'), Decimal('3.40'))
# (557, 'CA-2016-113243', 492, Decimal('20.70'), 2, Decimal('0.00'), Decimal('9.94'))
# (558, 'CA-2016-113243', 493, Decimal('1335.68'), 4, Decimal('0.20'), Decimal('-217.05'))
# (559, 'CA-2016-113243', 494, Decimal('32.40'), 5, Decimal('0.00'), Decimal('15.55'))
# (560, 'CA-2017-118731', 380, Decimal('42.60'), 3, Decimal('0.00'), Decimal('16.61'))
# (561, 'CA-2017-118731', 495, Decimal('84.06'), 7, Decimal('0.20'), Decimal('27.32'))
# (562, 'CA-2014-145576', 496, Decimal('13.00'), 5, Decimal('0.20'), Decimal('1.30'))
# (563, 'CA-2014-145576', 497, Decimal('13.13'), 3, Decimal('0.20'), Decimal('3.77'))
# (564, 'CA-2015-130736', 498, Decimal('3.96'), 2, Decimal('0.00'), Decimal('0.00'))
# (565, 'CA-2015-130736', 287, Decimal('2.61'), 1, Decimal('0.00'), Decimal('1.20'))
# ...
# (9811, 'US-2014-139640', 987, Decimal('120.77'), 4, Decimal('0.20'), Decimal('9.06'))
# (9812, 'CA-2016-117583', 1432, Decimal('25.92'), 4, Decimal('0.00'), Decimal('12.44'))
# (9813, 'CA-2016-117583', 333, Decimal('34.65'), 3, Decimal('0.00'), Decimal('9.70'))
# (9814, 'CA-2016-117583', 845, Decimal('204.95'), 5, Decimal('0.00'), Decimal('100.43'))
# (9815, 'CA-2016-117583', 1417, Decimal('79.95'), 5, Decimal('0.00'), Decimal('38.38'))
# (9816, 'CA-2015-162201', 1337, Decimal('173.49'), 7, Decimal('0.20'), Decimal('54.22'))
# (9817, 'CA-2015-162201', 771, Decimal('516.96'), 4, Decimal('0.20'), Decimal('-6.46'))
# (9818, 'CA-2015-162201', 1454, Decimal('173.21'), 7, Decimal('0.20'), Decimal('45.47'))
# (9819, 'CA-2015-162201', 451, Decimal('4.45'), 2, Decimal('0.20'), Decimal('0.33'))
# (9820, 'CA-2015-162201', 1572, Decimal('9.00'), 3, Decimal('0.20'), Decimal('3.15'))
# (9821, 'CA-2015-162201', 1767, Decimal('42.24'), 10, Decimal('0.20'), Decimal('13.20'))
# (9822, 'CA-2015-162201', 475, Decimal('18.26'), 2, Decimal('0.70'), Decimal('-13.39'))
# (9823, 'US-2014-164406', 547, Decimal('152.91'), 3, Decimal('0.00'), Decimal('42.81'))
# (9824, 'US-2014-164406', 1100, Decimal('92.94'), 3, Decimal('0.00'), Decimal('41.82'))
# (9825, 'US-2014-164406', 78, Decimal('17.86'), 4, Decimal('0.20'), Decimal('6.25'))
# (9826, 'US-2014-164406', 617, Decimal('46.44'), 3, Decimal('0.20'), Decimal('15.09'))
# (9827, 'US-2014-164406', 1235, Decimal('195.14'), 4, Decimal('0.20'), Decimal('-12.20'))
# (9828, 'CA-2017-169999', 561, Decimal('129.30'), 2, Decimal('0.00'), Decimal('6.46'))
# (9829, 'CA-2017-169999', 548, Decimal('11.57'), 3, Decimal('0.20'), Decimal('3.76'))
# (9830, 'US-2017-152842', 38, Decimal('242.35'), 3, Decimal('0.20'), Decimal('15.15'))
# (9831, 'CA-2014-113257', 1351, Decimal('319.97'), 4, Decimal('0.20'), Decimal('95.99'))
# (9832, 'CA-2014-113257', 50, Decimal('8.62'), 7, Decimal('0.60'), Decimal('-2.59'))
# (9833, 'CA-2014-133963', 1059, Decimal('3.98'), 1, Decimal('0.20'), Decimal('1.44'))
# (9834, 'CA-2017-130302', 266, Decimal('895.94'), 7, Decimal('0.20'), Decimal('190.39'))
# (9835, 'CA-2016-126627', 1476, Decimal('14.00'), 4, Decimal('0.60'), Decimal('-6.30'))
# (9836, 'CA-2016-126627', 806, Decimal('16.39'), 2, Decimal('0.80'), Decimal('-26.23'))
# (9837, 'US-2016-125402', 840, Decimal('10.90'), 5, Decimal('0.00'), Decimal('5.12'))
# (9838, 'US-2016-125402', 431, Decimal('29.60'), 2, Decimal('0.00'), Decimal('14.80'))
# (9839, 'US-2016-125402', 1150, Decimal('4.98'), 1, Decimal('0.00'), Decimal('2.29'))
# (9840, 'US-2016-125402', 1714, Decimal('479.98'), 3, Decimal('0.20'), Decimal('161.99'))
# (9841, 'US-2016-125402', 1737, Decimal('44.74'), 8, Decimal('0.20'), Decimal('4.47'))
# (9842, 'US-2016-125402', 832, Decimal('5.76'), 2, Decimal('0.00'), Decimal('1.67'))
# (9843, 'US-2016-125402', 667, Decimal('483.14'), 4, Decimal('0.20'), Decimal('60.39'))
# (9844, 'CA-2014-163867', 1150, Decimal('15.94'), 4, Decimal('0.20'), Decimal('5.18'))
# (9845, 'CA-2014-163867', 508, Decimal('61.54'), 7, Decimal('0.60'), Decimal('-40.00'))
# (9846, 'CA-2014-163867', 1135, Decimal('132.70'), 3, Decimal('0.20'), Decimal('9.95'))
# (9847, 'CA-2017-169327', 22, Decimal('43.10'), 5, Decimal('0.00'), Decimal('11.21'))
# (9848, 'CA-2017-169327', 748, Decimal('511.50'), 5, Decimal('0.00'), Decimal('132.99'))
# (9849, 'CA-2017-169327', 811, Decimal('147.92'), 5, Decimal('0.20'), Decimal('46.22'))
# (9850, 'CA-2014-142979', 1597, Decimal('39.68'), 2, Decimal('0.00'), Decimal('16.27'))
# (9851, 'CA-2016-158155', 549, Decimal('12.56'), 2, Decimal('0.00'), Decimal('4.02'))
# (9852, 'CA-2016-158155', 445, Decimal('90.48'), 3, Decimal('0.20'), Decimal('33.93'))
# (9853, 'CA-2016-158155', 1231, Decimal('13.08'), 2, Decimal('0.00'), Decimal('6.02'))
# (9854, 'CA-2016-158155', 597, Decimal('214.70'), 5, Decimal('0.00'), Decimal('83.73'))
# (9855, 'CA-2017-138870', 1625, Decimal('50.32'), 4, Decimal('0.00'), Decimal('21.13'))
# (9856, 'CA-2017-138870', 1514, Decimal('24.56'), 2, Decimal('0.00'), Decimal('11.54'))
# (9857, 'CA-2014-120950', 57, Decimal('43.68'), 6, Decimal('0.00'), Decimal('20.97'))
# (9858, 'CA-2015-164301', 413, Decimal('3393.68'), 8, Decimal('0.00'), Decimal('610.86'))
# (9859, 'CA-2017-113278', 147, Decimal('67.40'), 5, Decimal('0.00'), Decimal('17.52'))
# (9860, 'CA-2017-113278', 243, Decimal('2.52'), 2, Decimal('0.00'), Decimal('0.10'))
# (9861, 'CA-2017-113278', 1058, Decimal('67.80'), 4, Decimal('0.00'), Decimal('1.36'))
# (9862, 'CA-2017-113278', 1200, Decimal('18.76'), 2, Decimal('0.00'), Decimal('5.25'))
# (9863, 'CA-2017-113278', 429, Decimal('12.12'), 4, Decimal('0.00'), Decimal('2.55'))
# (9864, 'CA-2017-113278', 757, Decimal('11.34'), 1, Decimal('0.00'), Decimal('5.56'))
# (9865, 'CA-2017-113278', 241, Decimal('159.80'), 4, Decimal('0.00'), Decimal('70.31'))
# (9866, 'CA-2017-113278', 1193, Decimal('18.96'), 2, Decimal('0.00'), Decimal('8.53'))
# (9867, 'US-2015-116981', 1468, Decimal('1085.42'), 7, Decimal('0.00'), Decimal('282.21'))
# (9868, 'US-2015-116981', 1539, Decimal('13.11'), 3, Decimal('0.00'), Decimal('3.41'))
# (9869, 'CA-2014-114195', 597, Decimal('68.70'), 2, Decimal('0.20'), Decimal('16.32'))
# (9870, 'CA-2014-114195', 1607, Decimal('3.13'), 2, Decimal('0.70'), Decimal('-2.61'))
# (9871, 'CA-2014-114195', 446, Decimal('22.43'), 3, Decimal('0.70'), Decimal('-17.94'))
# (9872, 'CA-2017-146269', 246, Decimal('290.34'), 2, Decimal('0.20'), Decimal('32.66'))
# (9873, 'CA-2017-146269', 793, Decimal('19.15'), 2, Decimal('0.20'), Decimal('1.20'))
# (9874, 'CA-2016-100587', 1537, Decimal('6.48'), 1, Decimal('0.00'), Decimal('3.11'))
# (9875, 'CA-2016-166653', 896, Decimal('63.97'), 2, Decimal('0.20'), Decimal('19.99'))
# (9876, 'CA-2015-130855', 1879, Decimal('6.36'), 2, Decimal('0.00'), Decimal('0.06'))
# (9877, 'US-2017-166324', 1254, Decimal('848.54'), 4, Decimal('0.20'), Decimal('-21.21'))
# (9878, 'US-2017-166324', 1477, Decimal('8.70'), 5, Decimal('0.70'), Decimal('-6.38'))
# (9879, 'US-2017-166324', 1819, Decimal('122.38'), 3, Decimal('0.40'), Decimal('-24.48'))
# (9880, 'CA-2016-122581', 963, Decimal('573.17'), 7, Decimal('0.10'), Decimal('63.69'))
# (9881, 'CA-2015-104297', 259, Decimal('85.06'), 3, Decimal('0.20'), Decimal('28.71'))
# (9882, 'CA-2014-153927', 610, Decimal('14.04'), 3, Decimal('0.00'), Decimal('6.74'))
# (9883, 'CA-2014-153927', 924, Decimal('272.61'), 13, Decimal('0.00'), Decimal('98.14'))
# (9884, 'CA-2014-112291', 409, Decimal('11.16'), 2, Decimal('0.00'), Decimal('5.58'))
# (9885, 'CA-2014-112291', 1206, Decimal('62.31'), 3, Decimal('0.00'), Decimal('22.43'))
# (9886, 'CA-2014-112291', 1115, Decimal('159.98'), 2, Decimal('0.00'), Decimal('57.59'))
# (9887, 'CA-2014-146997', 498, Decimal('5.94'), 3, Decimal('0.00'), Decimal('0.00'))
# (9888, 'CA-2017-169607', 1241, Decimal('9.96'), 2, Decimal('0.00'), Decimal('4.68'))
# (9889, 'CA-2015-127544', 1115, Decimal('79.99'), 1, Decimal('0.00'), Decimal('28.80'))
# (9890, 'CA-2017-166499', 1729, Decimal('8.94'), 3, Decimal('0.00'), Decimal('2.41'))
# (9891, 'US-2016-115441', 1562, Decimal('20.62'), 2, Decimal('0.00'), Decimal('9.69'))
# (9892, 'US-2016-115441', 944, Decimal('124.25'), 7, Decimal('0.00'), Decimal('48.46'))
# (9893, 'US-2016-115441', 480, Decimal('297.55'), 5, Decimal('0.00'), Decimal('83.31'))
# (9894, 'US-2016-115441', 1747, Decimal('403.56'), 4, Decimal('0.00'), Decimal('96.85'))
# (9895, 'US-2016-115441', 286, Decimal('95.20'), 5, Decimal('0.00'), Decimal('27.61'))
# (9896, 'CA-2014-115049', 1589, Decimal('153.82'), 11, Decimal('0.20'), Decimal('38.46'))
# (9897, 'CA-2014-156342', 1696, Decimal('62.02'), 2, Decimal('0.20'), Decimal('22.48'))
# (9898, 'CA-2016-112830', 627, Decimal('466.32'), 3, Decimal('0.20'), Decimal('34.97'))
# (9899, 'CA-2016-112830', 1732, Decimal('82.64'), 2, Decimal('0.20'), Decimal('0.00'))
# (9900, 'US-2014-117380', 599, Decimal('330.59'), 1, Decimal('0.40'), Decimal('-143.25'))
# (9901, 'CA-2017-117646', 600, Decimal('237.10'), 3, Decimal('0.20'), Decimal('20.75'))
# (9902, 'CA-2017-117646', 1193, Decimal('22.75'), 3, Decimal('0.20'), Decimal('7.11'))
# (9903, 'CA-2017-117646', 145, Decimal('6.67'), 1, Decimal('0.20'), Decimal('2.08'))
# (9904, 'CA-2014-122609', 1393, Decimal('25.13'), 3, Decimal('0.60'), Decimal('-6.91'))
# (9905, 'CA-2014-122609', 430, Decimal('127.98'), 2, Decimal('0.20'), Decimal('25.60'))
# (9906, 'US-2015-129007', 1165, Decimal('131.88'), 7, Decimal('0.00'), Decimal('55.39'))
# (9907, 'US-2015-129007', 1134, Decimal('25.03'), 3, Decimal('0.20'), Decimal('7.82'))
# (9908, 'US-2015-129007', 1190, Decimal('717.72'), 3, Decimal('0.20'), Decimal('71.77'))
# (9909, 'US-2015-129007', 1504, Decimal('207.35'), 5, Decimal('0.00'), Decimal('24.88'))
# (9910, 'US-2015-129007', 951, Decimal('44.67'), 3, Decimal('0.00'), Decimal('12.06'))
# (9911, 'US-2015-129007', 928, Decimal('209.70'), 2, Decimal('0.00'), Decimal('100.66'))
# (9912, 'US-2014-157231', 91, Decimal('115.36'), 7, Decimal('0.00'), Decimal('56.53'))
# (9913, 'CA-2015-132388', 1332, Decimal('362.14'), 3, Decimal('0.20'), Decimal('-54.32'))
# (9914, 'CA-2015-132388', 1682, Decimal('31.05'), 3, Decimal('0.00'), Decimal('14.90'))
# (9915, 'CA-2017-160927', 1484, Decimal('12.96'), 2, Decimal('0.00'), Decimal('6.22'))
# (9916, 'CA-2017-160927', 645, Decimal('94.85'), 5, Decimal('0.00'), Decimal('45.53'))
# (9917, 'CA-2017-160927', 147, Decimal('13.48'), 1, Decimal('0.00'), Decimal('3.50'))
# (9918, 'CA-2017-160927', 531, Decimal('14.91'), 3, Decimal('0.00'), Decimal('4.62'))
# (9919, 'CA-2015-105508', 896, Decimal('39.98'), 1, Decimal('0.00'), Decimal('17.99'))
# (9920, 'CA-2016-149272', 83, Decimal('528.43'), 5, Decimal('0.30'), Decimal('-143.43'))
# (9921, 'CA-2016-149272', 1417, Decimal('22.39'), 7, Decimal('0.80'), Decimal('-35.82'))
# (9922, 'CA-2014-111360', 855, Decimal('5.74'), 3, Decimal('0.70'), Decimal('-4.59'))
# (9923, 'US-2017-162124', 883, Decimal('191.97'), 4, Decimal('0.20'), Decimal('28.80'))
# (9924, 'CA-2015-159534', 351, Decimal('49.85'), 3, Decimal('0.20'), Decimal('16.82'))
# (9925, 'CA-2015-159534', 245, Decimal('23.99'), 1, Decimal('0.00'), Decimal('12.00'))
# (9926, 'CA-2015-159534', 13, Decimal('1087.94'), 8, Decimal('0.20'), Decimal('353.58'))
# (9927, 'CA-2015-159534', 974, Decimal('199.98'), 2, Decimal('0.00'), Decimal('53.99'))
# (9928, 'CA-2015-159534', 1232, Decimal('83.92'), 4, Decimal('0.00'), Decimal('20.14'))
# (9929, 'CA-2016-129630', 74, Decimal('24.27'), 3, Decimal('0.00'), Decimal('8.74'))
# (9930, 'CA-2016-129630', 1306, Decimal('2799.96'), 5, Decimal('0.20'), Decimal('944.99'))
# (9931, 'CA-2015-104948', 1508, Decimal('9.87'), 2, Decimal('0.20'), Decimal('3.46'))
# (9932, 'CA-2015-104948', 1389, Decimal('683.33'), 4, Decimal('0.15'), Decimal('-40.20'))
# (9933, 'CA-2015-104948', 1554, Decimal('29.96'), 7, Decimal('0.00'), Decimal('13.48'))
# (9934, 'CA-2014-166555', 1535, Decimal('164.85'), 3, Decimal('0.00'), Decimal('47.81'))
# (9935, 'CA-2016-114405', 1835, Decimal('33.53'), 3, Decimal('0.20'), Decimal('2.51'))
# (9936, 'CA-2016-114405', 1893, Decimal('36.74'), 3, Decimal('0.20'), Decimal('3.67'))
# (9937, 'CA-2017-132955', 142, Decimal('102.93'), 3, Decimal('0.00'), Decimal('48.38'))
# (9938, 'CA-2016-164889', 981, Decimal('71.09'), 2, Decimal('0.20'), Decimal('-1.78'))
# (9939, 'CA-2016-169824', 1760, Decimal('60.35'), 5, Decimal('0.00'), Decimal('19.92'))
# (9940, 'CA-2016-169824', 1292, Decimal('35.52'), 4, Decimal('0.00'), Decimal('9.95'))
# (9941, 'CA-2016-169824', 909, Decimal('11.20'), 7, Decimal('0.00'), Decimal('4.82'))
# (9942, 'CA-2017-164028', 406, Decimal('223.58'), 14, Decimal('0.00'), Decimal('87.20'))
# (9943, 'CA-2014-143371', 1458, Decimal('998.82'), 9, Decimal('0.00'), Decimal('29.96'))
# (9944, 'CA-2014-143371', 687, Decimal('51.15'), 5, Decimal('0.00'), Decimal('13.30'))
# (9945, 'CA-2015-145415', 1042, Decimal('40.74'), 3, Decimal('0.00'), Decimal('0.41'))
# (9946, 'CA-2014-111157', 1469, Decimal('3.42'), 1, Decimal('0.20'), Decimal('1.07'))
# (9947, 'CA-2014-111157', 730, Decimal('151.20'), 3, Decimal('0.20'), Decimal('32.13'))
# (9948, 'CA-2017-121559', 628, Decimal('1925.88'), 6, Decimal('0.00'), Decimal('539.25'))
# (9949, 'CA-2017-121559', 228, Decimal('2405.20'), 8, Decimal('0.00'), Decimal('793.72'))
# (9950, 'CA-2017-121559', 1140, Decimal('83.97'), 3, Decimal('0.00'), Decimal('15.95'))
# (9951, 'CA-2017-121559', 690, Decimal('39.89'), 1, Decimal('0.00'), Decimal('14.76'))
# (9952, 'CA-2017-121559', 850, Decimal('17.38'), 2, Decimal('0.00'), Decimal('8.69'))
# (9953, 'CA-2015-141593', 304, Decimal('55.26'), 2, Decimal('0.20'), Decimal('20.72'))
# (9954, 'CA-2015-141593', 1362, Decimal('6.48'), 1, Decimal('0.00'), Decimal('3.11'))
# (9955, 'CA-2015-141593', 1413, Decimal('34.25'), 3, Decimal('0.20'), Decimal('11.56'))
# (9956, 'CA-2015-141593', 984, Decimal('273.57'), 2, Decimal('0.20'), Decimal('10.26'))
# (9957, 'US-2014-143287', 1299, Decimal('46.35'), 5, Decimal('0.00'), Decimal('21.78'))
# (9958, 'US-2014-143287', 1582, Decimal('223.92'), 4, Decimal('0.00'), Decimal('109.72'))
# (9959, 'US-2014-143287', 507, Decimal('7.30'), 2, Decimal('0.00'), Decimal('2.19'))
# (9960, 'CA-2017-137421', 1690, Decimal('9.34'), 2, Decimal('0.20'), Decimal('1.87'))
# (9961, 'CA-2017-141446', 1564, Decimal('18.00'), 1, Decimal('0.00'), Decimal('3.24'))
# (9962, 'CA-2015-168088', 1137, Decimal('65.58'), 2, Decimal('0.20'), Decimal('23.77'))
# (9963, 'CA-2015-168088', 1628, Decimal('383.47'), 4, Decimal('0.32'), Decimal('-67.67'))
# (9964, 'CA-2015-143700', 942, Decimal('10.37'), 2, Decimal('0.20'), Decimal('3.63'))
# (9965, 'CA-2016-146374', 279, Decimal('13.40'), 1, Decimal('0.00'), Decimal('6.43'))
# (9966, 'CA-2016-146374', 817, Decimal('4.98'), 1, Decimal('0.00'), Decimal('2.34'))
# (9967, 'CA-2016-146374', 1374, Decimal('109.69'), 7, Decimal('0.00'), Decimal('51.55'))
# (9968, 'CA-2017-153871', 1242, Decimal('40.20'), 5, Decimal('0.00'), Decimal('18.09'))
# (9969, 'CA-2017-153871', 1519, Decimal('735.98'), 2, Decimal('0.00'), Decimal('331.19'))
# (9970, 'CA-2017-153871', 190, Decimal('22.75'), 7, Decimal('0.00'), Decimal('6.60'))
# (9971, 'CA-2015-103772', 988, Decimal('119.56'), 2, Decimal('0.00'), Decimal('55.00'))
# (9972, 'CA-2015-103772', 1281, Decimal('140.75'), 5, Decimal('0.00'), Decimal('42.22'))
# (9973, 'CA-2016-130225', 638, Decimal('99.57'), 2, Decimal('0.20'), Decimal('33.60'))
# (9974, 'US-2016-103674', 1819, Decimal('271.96'), 5, Decimal('0.20'), Decimal('27.20'))
# (9975, 'US-2016-103674', 1136, Decimal('18.69'), 7, Decimal('0.00'), Decimal('5.23'))
# (9976, 'US-2016-103674', 583, Decimal('13.36'), 2, Decimal('0.00'), Decimal('6.41'))
# (9977, 'US-2016-103674', 499, Decimal('249.58'), 2, Decimal('0.20'), Decimal('31.20'))
# (9978, 'US-2016-103674', 498, Decimal('13.86'), 7, Decimal('0.00'), Decimal('0.00'))
# (9979, 'US-2016-103674', 813, Decimal('13.38'), 4, Decimal('0.20'), Decimal('4.68'))
# (9980, 'US-2016-103674', 1800, Decimal('437.47'), 14, Decimal('0.20'), Decimal('153.12'))
# (9981, 'US-2015-151435', 986, Decimal('85.98'), 1, Decimal('0.00'), Decimal('22.35'))
# (9982, 'CA-2017-163566', 622, Decimal('16.52'), 5, Decimal('0.20'), Decimal('5.37'))
# (9983, 'US-2016-157728', 732, Decimal('35.56'), 7, Decimal('0.00'), Decimal('16.71'))
# (9984, 'US-2016-157728', 1719, Decimal('97.98'), 2, Decimal('0.00'), Decimal('27.43'))
# (9985, 'CA-2015-100251', 366, Decimal('31.50'), 10, Decimal('0.00'), Decimal('15.12'))
# (9986, 'CA-2015-100251', 1215, Decimal('55.60'), 4, Decimal('0.00'), Decimal('16.12'))
# (9987, 'CA-2016-125794', 1540, Decimal('36.24'), 1, Decimal('0.00'), Decimal('15.22'))
# (9988, 'CA-2017-163629', 1620, Decimal('79.99'), 1, Decimal('0.00'), Decimal('28.80'))
# (9989, 'CA-2017-163629', 1815, Decimal('206.10'), 5, Decimal('0.00'), Decimal('55.65'))
# (9990, 'CA-2014-110422', 1182, Decimal('25.25'), 3, Decimal('0.20'), Decimal('4.10'))
# (9991, 'CA-2017-121258', 1793, Decimal('91.96'), 2, Decimal('0.00'), Decimal('15.63'))
# (9992, 'CA-2017-121258', 298, Decimal('258.58'), 2, Decimal('0.20'), Decimal('19.39'))
# (9993, 'CA-2017-121258', 964, Decimal('29.60'), 4, Decimal('0.00'), Decimal('13.32'))
# (9994, 'CA-2017-119914', 167, Decimal('243.16'), 2, Decimal('0.00'), Decimal('72.95'))

# %%
# Add foreign key to the tables
cursor.execute("ALTER TABLE transaction ADD FOREIGN KEY (product_id) REFERENCES product(product_id)");
cursor.execute("ALTER TABLE transaction ADD FOREIGN KEY (order_id) REFERENCES order_detailed(order_id)");
cursor.execute("ALTER TABLE order_detailed ADD FOREIGN KEY (address_id) REFERENCES customer_address(address_id)");
cursor.execute("ALTER TABLE order_detailed ADD FOREIGN KEY (customer_id) REFERENCES customer_information(customer_id)");
cursor.execute("ALTER TABLE product ADD FOREIGN KEY (sub_categories) REFERENCES product_detailed(sub_categories)");

# %%
# Run the SQL scripts to get the original data format
cursor.execute("""
    select t.transaction_id as 'Row ID', t.order_id as 'Order ID', o.order_date as 'Order Date', o.ship_date as 'Ship Date', o.ship_mode as ' Ship Mode', 
    o.customer_id as 'Customer ID', inf.customer_name as ' Customer Name', inf.segment as 'Segment', ad.country as 'Country', ad.city as 'City', 
    ad.state as 'State', ad.postal_code as 'Postal Code', ad.region as ' Region', p.product_code as 'Product ID', de.categories as 'Category', p.sub_categories as 'Sub-Category',  
    p.product_name as 'Product Name', t.sales as 'Sales', t.Quantity AS 'Quantity', t.discount AS 'Discount', t.profit AS 'Profit'
    from walmart.transaction t
    left join walmart.order_detailed o
    on t.order_id = o.order_id
    left join walmart.customer_information inf
    on o.customer_id = inf.customer_id
    left join walmart.customer_address ad
    on o.address_id = ad.address_id
    left join walmart.product p
    on t.product_id = p.product_id
    left join walmart.product_detailed de
    on p.sub_categories =  de.sub_categories
    order by t.transaction_id;
""")

# %%
# Get the result from SQL Script
rows = cursor.fetchall()
columns = [desc[0] for desc in cursor.description]
df3 = pd.DataFrame(rows, columns=columns)
df3 = df3.sort_values(by='Row ID')
df3
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  2016-11-08  2016-11-11    Second Class
# 1          2  CA-2016-152156  2016-11-08  2016-11-11    Second Class
# 2          3  CA-2016-138688  2016-06-12  2016-06-16    Second Class
# 3          4  US-2015-108966  2015-10-11  2015-10-18  Standard Class
# 4          5  US-2015-108966  2015-10-11  2015-10-18  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422  2014-01-21  2014-01-23    Second Class
# 9990    9991  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9991    9992  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9992    9993  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9993    9994  CA-2017-119914  2017-05-04  2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name   Sales Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.96        2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94        3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.62        2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.58        5
# 4                        Eldon Fold 'N Roll Cart System   22.37        2
# ...                                                 ...     ...      ...
# 9989                             Ultra Door Pull Handle   25.25        3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.96        2
# 9991                              Aastra 57i VoIP phone  258.58        2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.60        4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.16        2
#
#       Discount   Profit
# 0         0.00    41.91
# 1         0.00   219.58
# 2         0.00     6.87
# 3         0.45  -383.03
# 4         0.20     2.52
# ...        ...      ...
# 9989      0.20     4.10
# 9990      0.00    15.63
# 9991      0.20    19.39
# 9992      0.00    13.32
# 9993      0.00    72.95
#
# [9994 rows x 21 columns]

# %%
# Get the columns from SQL Scripts
df3.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df3.reset_index(drop=True, inplace=True)
df3
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156  2016-11-08  2016-11-11    Second Class
# 1          2  CA-2016-152156  2016-11-08  2016-11-11    Second Class
# 2          3  CA-2016-138688  2016-06-12  2016-06-16    Second Class
# 3          4  US-2015-108966  2015-10-11  2015-10-18  Standard Class
# 4          5  US-2015-108966  2015-10-11  2015-10-18  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422  2014-01-21  2014-01-23    Second Class
# 9990    9991  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9991    9992  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9992    9993  CA-2017-121258  2017-02-26  2017-03-03  Standard Class
# 9993    9994  CA-2017-119914  2017-05-04  2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# 1       CG-12520       Claire Gute   Consumer  United States        Henderson
# 2       DV-13045   Darrin Van Huff  Corporate  United States      Los Angeles
# 3       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4       SO-20335    Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...          ...               ...        ...            ...              ...
# 9989    TB-21400  Tom Boeckenhauer   Consumer  United States            Miami
# 9990    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9991    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9992    DB-13060       Dave Brooks   Consumer  United States       Costa Mesa
# 9993    CC-12220      Chris Cortes   Consumer  United States      Westminster
#
#       ... Postal Code  Region       Product ID         Category Sub-Category  \
# 0     ...       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1     ...       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2     ...       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3     ...       33311   South  FUR-TA-10000577        Furniture       Tables
# 4     ...       33311   South  OFF-ST-10000760  Office Supplies      Storage
# ...   ...         ...     ...              ...              ...          ...
# 9989  ...       33180   South  FUR-FU-10001889        Furniture  Furnishings
# 9990  ...       92627    West  FUR-FU-10000747        Furniture  Furnishings
# 9991  ...       92627    West  TEC-PH-10003645       Technology       Phones
# 9992  ...       92627    West  OFF-PA-10004041  Office Supplies        Paper
# 9993  ...       92683    West  OFF-AP-10002684  Office Supplies   Appliances
#
#                                            Product Name   Sales Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.96        2
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94        3
# 2     Self-Adhesive Address Labels for Typewriters b...   14.62        2
# 3         Bretford CR4500 Series Slim Rectangular Table  957.58        5
# 4                        Eldon Fold 'N Roll Cart System   22.37        2
# ...                                                 ...     ...      ...
# 9989                             Ultra Door Pull Handle   25.25        3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.96        2
# 9991                              Aastra 57i VoIP phone  258.58        2
# 9992  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.60        4
# 9993  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.16        2
#
#       Discount   Profit
# 0         0.00    41.91
# 1         0.00   219.58
# 2         0.00     6.87
# 3         0.45  -383.03
# 4         0.20     2.52
# ...        ...      ...
# 9989      0.20     4.10
# 9990      0.00    15.63
# 9991      0.20    19.39
# 9992      0.00    13.32
# 9993      0.00    72.95
#
# [9994 rows x 21 columns]

# %%
# Caomparing the columns headers to repare for checking
print(df.columns == df3.columns)
# Out:
# [ True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True]

# %%
# Chewck if normalization of data is correct
check = df.compare(df3)

# %%
# Check the differences
check
# Out:
#        Sales         Discount        Profit
#         self   other     self other    self    other
# 0     261.96  261.96      NaN   NaN   41.91    41.91
# 1     731.94  731.94      NaN   NaN  219.58   219.58
# 2      14.62   14.62      NaN   NaN    6.87     6.87
# 3     957.58  957.58     0.45  0.45 -383.03  -383.03
# 4      22.37   22.37     0.20  0.20    2.52     2.52
# ...      ...     ...      ...   ...     ...      ...
# 9989     NaN     NaN     0.20  0.20    4.10     4.10
# 9990   91.96   91.96      NaN   NaN   15.63    15.63
# 9991  258.58  258.58     0.20  0.20   19.39    19.39
# 9992   29.60   29.60      NaN   NaN   13.32    13.32
# 9993  243.16  243.16      NaN   NaN   72.95    72.95
#
# [9965 rows x 6 columns]
